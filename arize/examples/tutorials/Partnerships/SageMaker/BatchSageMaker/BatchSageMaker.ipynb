# %% [markdown]
# # Amazon SageMaker Batch Transform: Associate prediction results with their corresponding input records
# _**Use SageMaker's XGBoost to train a binary classification model and for a list of tumors in batch file, predict if each is malignant**_
#
# _**It also shows how to use the input output joining / filter feature in Batch transform in details**_
#
# ---
#
#
#
# ## Background
# This purpose of this notebook is to train a model using SageMaker's XGBoost and UCI's breast cancer diagnostic data set to illustrate at how to run batch inferences and how to use the Batch Transform I/O join feature. UCI's breast cancer diagnostic data set is available at https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29. The data set is also available on Kaggle at https://www.kaggle.com/uciml/breast-cancer-wisconsin-data. The purpose here is to use this data set to build a predictve model of whether a breast mass image indicates benign or malignant tumor.

# %% [markdown]
# ### File Architecture
# This file creates the following architecture for processing batch transforms. The architecture setups up a batch transformer, creates an event where data is passed to a lambda function that then processes the inputs & predictions.
#
#
# <img src="http://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/batch_a.png?" width="500" height="600">

# %% [markdown]
# ---
#
# ## Setup
#
# Let's start by specifying:
#
# * The SageMaker role arn used to give training and batch transform access to your data. The snippet below will use the same role used by your SageMaker notebook instance. Otherwise, specify the full ARN of a role with the SageMakerFullAccess policy attached.
# * The S3 bucket that you want to use for training and storing model objects.

# %%
import os
import boto3
import sagemaker

role = sagemaker.get_execution_role()
sess = sagemaker.Session()

bucket=sess.default_bucket()
prefix = 'sagemaker/breast-cancer-prediction-xgboost' # place to upload training files within the bucket

# %%
bucket
# Out:
# 'sagemaker-us-east-2-783112096916'

# %% [markdown]
# ---
# ## Data preparation
#
# Data Source: https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data
#         https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# Let's download the data and save it in the local folder with the name data.csv and take a look at it.

# %%
import pandas as pd
import numpy as np

#data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header = None)
data = pd.read_csv('https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/datasets_180_408_data.csv')

print(data)
# specify columns extracted from wbdc.names
data.columns = ["id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean",
                "compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean",
                "radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se",
                "concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst",
                "perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst",
                "concave points_worst","symmetry_worst","fractal_dimension_worst", "remove_col"]
data = data.drop(['remove_col'], axis=1)
# save the data
data.to_csv("data.csv", sep=',', index=False)

data.sample(8)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 74    8610175         B        12.31         16.52           79.19      470.9
# 324  89511501         B        12.20         15.21           78.01      457.9
# 411    905520         B        11.04         16.83           70.92      373.2
# 386    902975         B        12.21         14.09           78.78      462.0
# 6      844359         M        18.25         19.98          119.60     1040.0
# 487    913505         M        19.44         18.82          128.10     1167.0
# 168   8712766         M        17.47         24.68          116.10      984.6
# 128    866458         B        15.10         16.39           99.58      674.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 74           0.09172           0.06829         0.03372              0.02272
# 324          0.08673           0.06545         0.01994              0.01692
# 411          0.10770           0.07804         0.03046              0.02480
# 386          0.08108           0.07823         0.06839              0.02534
# 6            0.09463           0.10900         0.11270              0.07400
# 487          0.10890           0.14480         0.22560              0.11940
# 168          0.10490           0.16030         0.21590              0.10430
# 128          0.11500           0.18070         0.11380              0.08534
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 74   ...         14.11          23.21            89.71       611.1
# 324  ...         13.75          21.38            91.11       583.1
# 411  ...         12.41          26.44            79.93       471.4
# 386  ...         13.13          19.29            87.65       529.9
# 6    ...         22.88          27.66           153.20      1606.0
# 487  ...         23.96          30.39           153.90      1740.0
# 168  ...         23.14          32.33           155.30      1660.0
# 128  ...         16.11          18.33           105.90       762.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 74             0.1176             0.1843           0.1703
# 324            0.1256             0.1928           0.1167
# 411            0.1369             0.1482           0.1067
# 386            0.1026             0.2431           0.3076
# 6              0.1442             0.2576           0.3784
# 487            0.1514             0.3725           0.5936
# 168            0.1376             0.3830           0.4890
# 128            0.1386             0.2883           0.1960
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 74                0.08660          0.2618                  0.07609
# 324               0.05556          0.2661                  0.07961
# 411               0.07431          0.2998                  0.07881
# 386               0.09140          0.2677                  0.08824
# 6                 0.19320          0.3063                  0.08368
# 487               0.20600          0.3266                  0.09009
# 168               0.17210          0.2160                  0.09300
# 128               0.14230          0.2590                  0.07779
#
# [8 rows x 32 columns]

# %% [markdown]
# #### Key observations:
# * The data has 569 observations and 32 columns.
# * The first field is the 'id' attribute that we will want to drop before batch inference and add to the final inference output next to the probability of malignancy.
# * Second field, 'diagnosis', is an indicator of the actual diagnosis ('M' = Malignant; 'B' = Benign).
# * There are 30 other numeric features that we will use for training and inferencing.

# %% [markdown]
# Let's replace the M/B diagnosis with a 1/0 boolean value.

# %%
data['diagnosis']=data['diagnosis'].apply(lambda x: ((x =="M"))+0)
data.sample(8)
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426          0       13.540         14.36           87.46      566.3
# 301   892604          0       12.460         19.89           80.43      471.3
# 108    86355          1       22.270         19.67          152.80     1509.0
# 89    861598          0       14.640         15.24           95.77      651.9
# 483   912558          0       13.700         17.64           87.76      571.1
# 152  8710441          0        9.731         15.34           63.78      300.2
# 475   911408          0       12.830         15.73           82.89      506.9
# 41    855563          1       10.950         21.35           71.90      371.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 19           0.09779           0.08129         0.06664              0.04781
# 301          0.08451           0.10140         0.06830              0.03099
# 108          0.13260           0.27680         0.42640              0.18230
# 89           0.11320           0.13390         0.09966              0.07064
# 483          0.09950           0.07957         0.04548              0.03160
# 152          0.10720           0.15990         0.41080              0.07857
# 475          0.09040           0.08269         0.05835              0.03078
# 41           0.12270           0.12180         0.10440              0.05669
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 19   ...         15.11          19.26            99.70       711.2
# 301  ...         13.46          23.07            88.13       551.3
# 108  ...         28.40          28.01           206.80      2360.0
# 89   ...         16.34          18.24           109.40       803.6
# 483  ...         14.96          23.53            95.78       686.5
# 152  ...         11.02          19.49            71.04       380.5
# 475  ...         14.09          19.35            93.22       605.8
# 41   ...         12.84          35.34            87.22       514.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 19             0.1440             0.1773           0.2390
# 301            0.1050             0.2158           0.1904
# 108            0.1701             0.6997           0.9608
# 89             0.1277             0.3089           0.2604
# 483            0.1199             0.1346           0.1742
# 152            0.1292             0.2772           0.8216
# 475            0.1326             0.2610           0.3476
# 41             0.1909             0.2698           0.4023
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 19                0.12880          0.2977                  0.07259
# 301               0.07625          0.2685                  0.07764
# 108               0.29100          0.4055                  0.09789
# 89                0.13970          0.3151                  0.08473
# 483               0.09077          0.2518                  0.06960
# 152               0.15710          0.3108                  0.12590
# 475               0.09783          0.3006                  0.07802
# 41                0.14240          0.2964                  0.09606
#
# [8 rows x 32 columns]

# %% [markdown]
# Let's split the data as follows: 80% for training, 10% for validation and let's set 10% aside for our batch inference job. In addition, let's drop the 'id' field on the training set and validation set as 'id' is not a training feature. For our batch set however, we keep the 'id' feature. We'll want to filter it out prior to running our inferences so that the input data features match the ones of training set and then ultimately, we'll want to join it with inference result. We are however dropping the diagnosis attribute for the batch set since this is what we'll try to predict.

# %%
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.14710  ...        25.380          17.33           184.60
# 1                0.07017  ...        24.990          23.41           158.80
# 2                0.12790  ...        23.570          25.53           152.50
# 3                0.10520  ...        14.910          26.50            98.87
# 4                0.10430  ...        22.540          16.67           152.20
# ..                   ...  ...           ...            ...              ...
# 564              0.13890  ...        25.450          26.40           166.10
# 565              0.09791  ...        23.690          38.25           155.00
# 566              0.05302  ...        18.980          34.12           126.70
# 567              0.15200  ...        25.740          39.42           184.60
# 568              0.00000  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
#data split in three sets, training, validation and batch inference
rand_split = np.random.rand(len(data))
train_list = rand_split < 0.8
val_list = (rand_split >= 0.8) & (rand_split < 0.9)
batch_list = rand_split >= 0.9

data_train = data[train_list].drop(['id'],axis=1)
data_val = data[val_list].drop(['id'],axis=1)
data_batch = data[batch_list].drop(['diagnosis'],axis=1)
data_batch_noID = data_batch.drop(['id'],axis=1)

# %% [markdown]
# Let's upload those data sets in S3

# %%
train_file = 'train_data.csv'
data_train.to_csv(train_file,index=False,header=False)
sess.upload_data(train_file, key_prefix='{}/train'.format(prefix))

validation_file = 'validation_data.csv'
data_val.to_csv(validation_file,index=False,header=False)
sess.upload_data(validation_file, key_prefix='{}/validation'.format(prefix))

batch_file = 'batch_data.csv'
data_batch.to_csv(batch_file,index=False,header=False)
sess.upload_data(batch_file, key_prefix='{}/batch'.format(prefix))

batch_file_noID = 'batch_data_noID.csv'
data_batch_noID.to_csv(batch_file_noID,index=False,header=False)
sess.upload_data(batch_file_noID, key_prefix='{}/batch'.format(prefix))
# Out:
# 's3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/batch/batch_data_noID.csv'

# %%
#Arize addition
### This was added to track the feature columns
#XGBOOst does not allow a header in the CSV to keep the column names, in order to allow
#THE columns to travel with the data we save it to a file to be read back at the same time
features_file = 'features.csv'
data_batch.drop(columns=['id']).columns.to_series().to_csv(features_file,header=['features'], index=False)
features_file = sess.upload_data(features_file, key_prefix='{}/features'.format(prefix))
features_file
# Out:
# 's3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/features/features.csv'

# %% [markdown]
# ---
#
# ## Training job and model creation

# %% [markdown]
# The below cell uses the [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) to kick off the training job using both our training set and validation set. Not that the objective is set to 'binary:logistic' which trains a model to output a probability between 0 and 1 (here the probability of a tumor being malignant).

# %%
# %%time
from time import gmtime, strftime
from sagemaker.amazon.amazon_estimator import get_image_uri


job_name = 'xgb-' + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
output_location = 's3://{}/{}/output/{}'.format(bucket, prefix, job_name)
image = get_image_uri(boto3.Session().region_name, 'xgboost')

sm_estimator = sagemaker.estimator.Estimator(image,
                                             role,
                                             train_instance_count=1,
                                             train_instance_type='ml.m5.4xlarge',
                                             train_volume_size=50,
                                             input_mode='File',
                                             output_path=output_location,
                                             sagemaker_session=sess)

sm_estimator.set_hyperparameters(objective="binary:logistic",
                                 max_depth=5,
                                 eta=0.2,
                                 gamma=4,
                                 min_child_weight=6,
                                 subsample=0.8,
                                 silent=0,
                                 num_round=100)

train_data = sagemaker.session.s3_input('s3://{}/{}/train'.format(bucket, prefix), distribution='FullyReplicated',
                                        content_type='text/csv', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input('s3://{}/{}/validation'.format(bucket, prefix), distribution='FullyReplicated',
                                             content_type='text/csv', s3_data_type='S3Prefix')
data_channels = {'train': train_data, 'validation': validation_data}


# Start training by calling the fit method in the estimator
sm_estimator.fit(inputs=data_channels, logs=True)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-07-29 22:08:38 Starting - Starting the training job...
# 2020-07-29 22:08:39 Starting - Launching requested ML instances......
# 2020-07-29 22:09:44 Starting - Preparing the instances for training...
# 2020-07-29 22:10:24 Downloading - Downloading input data...
# 2020-07-29 22:11:05 Training - Training image download completed. Training in progress.
# 2020-07-29 22:11:05 Uploading - Uploading generated training model
# 2020-07-29 22:11:05 Completed - Training job completed
# Arguments: train
# [2020-07-29:22:10:53:INFO] Running standalone xgboost training.
# [2020-07-29:22:10:53:INFO] File size need to be processed in the node: 0.13mb. Available memory size in the node: 55495.22mb
# [2020-07-29:22:10:53:INFO] Determined delimiter of CSV input is ','
# [22:10:53] S3DistributionType set as FullyReplicated
# [22:10:53] 455x30 matrix with 13650 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-07-29:22:10:53:INFO] Determined delimiter of CSV input is ','
# [22:10:53] S3DistributionType set as FullyReplicated
# [22:10:53] 63x30 matrix with 1890 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=2
# [0]#011train-error:0.065934#011validation-error:0.047619
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [1]#011train-error:0.059341#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [2]#011train-error:0.046154#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [3]#011train-error:0.046154#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [4]#011train-error:0.041758#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [5]#011train-error:0.037363#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [6]#011train-error:0.030769#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [7]#011train-error:0.028571#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [8]#011train-error:0.026374#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [9]#011train-error:0.028571#011validation-error:0.047619
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [10]#011train-error:0.026374#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [11]#011train-error:0.026374#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]#011train-error:0.024176#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [13]#011train-error:0.021978#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 2 pruned nodes, max_depth=1
# [14]#011train-error:0.021978#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 2 pruned nodes, max_depth=1
# [15]#011train-error:0.01978#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [16]#011train-error:0.015385#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [17]#011train-error:0.015385#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [18]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 2 pruned nodes, max_depth=1
# [19]#011train-error:0.015385#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [20]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [21]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [22]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [24]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [25]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [26]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [27]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [28]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [29]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [30]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [31]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [32]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [33]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [34]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [35]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [36]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [37]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [38]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [39]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [40]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [41]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [42]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [43]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [44]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [45]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [46]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [47]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [48]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [49]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [50]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [51]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [52]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [53]#011train-error:0.010989#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [54]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [55]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [56]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [57]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [58]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [59]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [60]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [61]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [62]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [63]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [64]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [65]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [66]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [67]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [68]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [69]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [70]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [71]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [72]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [73]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [74]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [75]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [76]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [77]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [78]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [79]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [80]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [81]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [82]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [83]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [84]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [85]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [86]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [87]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [88]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [89]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [90]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [91]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [92]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [93]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [94]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [95]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [96]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [97]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [98]#011train-error:0.013187#011validation-error:0.031746
# [22:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [99]#011train-error:0.013187#011validation-error:0.031746
# Training seconds: 41
# Billable seconds: 41
# CPU times: user 378 ms, sys: 34.8 ms, total: 412 ms
# Wall time: 2min 41s

# %% [markdown]
# ---
#
# ## Batch Transform
#
# In SageMaker Batch Transform, we introduced 3 new attributes - __input_filter__, __join_source__ and __output_filter__. Please refer to [this page](https://docs.aws.amazon.com/sagemaker/latest/dg/batch-transform-data-processing.html) to learn more about how to use them.

# %%
#Setup Environment vaiables for Batch Transform
input_location = 's3://{}/{}/batch/{}'.format(bucket, prefix, batch_file_noID) # use input data without ID column
#Arize Batch Transform Enviornment Variables
model_name = 'sage_batch_test'
#Empty string model version is just date of batch
model_version = 'test_v_1.0'
batch_id =  "batch_10" #Should be set to different value every batch
#These are added so the event that picks up the finishing of the Transform has access to them
env_var = {'ArizeMonitor':'1','prefix':prefix, 'batch_file':batch_file_noID, 'bucket':bucket,
          'features_file':features_file, 'input_location':input_location,
          'model_name':model_name, 'model_version' : model_version,
          'batch_id':batch_id} #Batch ID is used to build prediction IDs and Match back to actuals

# %%
import json
import io
from urllib.parse import urlparse

def get_csv_output_from_s3(s3uri, file_name):
    parsed_url = urlparse(s3uri)
    bucket_name = parsed_url.netloc
    prefix = parsed_url.path[1:]
    s3 = boto3.resource('s3')
    obj = s3.Object(bucket_name, '{}/{}'.format(prefix, file_name))
    return obj.get()["Body"].read().decode('utf-8')

# %%
env_var = {'ArizeMonitor':'1','prefix':prefix, 'batch_file':batch_file_noID, 'bucket':bucket,
          'features_file':features_file, 'input_location':input_location,
          'model_name':model_name, 'model_version' : model_version,
          'batch_id':batch_id}

# %% [markdown]
# ### Creating A Lambda GZIP
# In order to create a lambda function you need to zip up all the libraries and place it on S3. The below code copies the arize required libraries and those neeeded for the lambda. This build is done on an Amazon server as it will put the right Numpy files / this ZIP won't work correctly if built on a MAC as Numpy on a MAC is different than Numpy for AWS.
#
# Needs to be same Python Version 3.6 (as where the following packages are built)
# Needs access to S3 Dir Resource
# Needs timeout to be 10-15 seconds
#
# ##### Lambda File
# The Lambda Function is in the file Lambda_function.py
# You must set the API_KEY and SPACE_KEY in that file, which is pushed to the Lambda Server

# %%
# !mkdir lambda_package
# Out:
# mkdir: cannot create directory ‘lambda_package’: File exists

# %%
# !mkdir lambda_pkg
# !pip install arize -t ./lambda_pkg/
# !pip install boto3 -t ./lambda_pkg/
# !pip install s3fs -t ./lambda_pkg/
# !pip install datetime -t ./lambda_pkg/\
# !pip install concurrent -t ./lambda_pkg/
# !cp lambda_function.py ./lambda_pkg/lambda_function.py
# %cd lambda_pkg
# !zip -r ../myArizeDeploymentPackage.zip *
# %cd ..
# Out:
# mkdir: cannot create directory ‘lambda_pkg’: File exists
# Collecting arize
#   Using cached arize-0.0.20-py2.py3-none-any.whl (16 kB)
# Collecting numpy==1.18.4
#   Using cached numpy-1.18.4-cp36-cp36m-manylinux1_x86_64.whl (20.2 MB)
# Processing /home/ec2-user/.cache/pip/wheels/35/8d/af/a922cb18800b31fadac3523cadf6c1efdf233b788fe7a4da70/googleapis_common_protos-1.51.0-py3-none-any.whl
# Collecting pandas==1.0.3
#   Using cached pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0 MB)
# Collecting protobuf==3.11.3
#   Using cached protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Processing /home/ec2-user/.cache/pip/wheels/15/03/c1/78bc17e91a6f740565af018749431a5c35e62ee93a32824344/requests_futures-1.0.0-py3-none-any.whl
# Collecting python-dateutil>=2.6.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting pytz>=2017.2
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting six>=1.9
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting setuptools
#   Using cached setuptools-49.2.0-py3-none-any.whl (789 kB)
# Collecting requests>=1.2.0
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# ERROR: spyder 4.1.2 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 4.1.2 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: jupyterlab 1.2.6 has requirement jupyterlab_server~=1.0.0, but you'll have jupyterlab-server 1.1.0 which is incompatible.
# ERROR: astroid 2.3.3 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.
# Installing collected packages: numpy, six, setuptools, protobuf, googleapis-common-protos, python-dateutil, pytz, pandas, certifi, chardet, idna, urllib3, requests, requests-futures, arize
# Successfully installed arize-0.0.20 certifi-2020.6.20 chardet-3.0.4 googleapis-common-protos-1.51.0 idna-2.10 numpy-1.18.4 pandas-1.0.3 protobuf-3.11.3 python-dateutil-2.8.1 pytz-2020.1 requests-2.24.0 requests-futures-1.0.0 setuptools-49.2.0 six-1.15.0 urllib3-1.25.10
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/arize-0.0.20.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/requests-2.24.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pytz-2020.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/googleapis_common_protos-1.51.0-py3.6-nspkg.pth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/arize already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/requests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/protobuf-3.11.3-py3.6-nspkg.pth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six-1.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/setuptools-49.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/idna-2.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/chardet already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/easy_install.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/certifi-2020.6.20.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/numpy-1.18.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/google already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pandas already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/protobuf-3.11.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/requests_futures-1.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/setuptools already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/python_dateutil-2.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pkg_resources already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/requests_futures already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pandas-1.0.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/chardet-3.0.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pytz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/certifi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/googleapis_common_protos-1.51.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3-1.25.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting boto3
#   Using cached boto3-1.14.31-py2.py3-none-any.whl (129 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.18.0,>=1.17.31
#   Using cached botocore-1.17.31-py2.py3-none-any.whl (6.4 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting docutils<0.16,>=0.10
#   Using cached docutils-0.15.2-py3-none-any.whl (547 kB)
# Collecting python-dateutil<3.0.0,>=2.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting urllib3<1.26,>=1.20; python_version != "3.4"
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting six>=1.5
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: jupyterlab 1.2.6 has requirement jupyterlab_server~=1.0.0, but you'll have jupyterlab-server 1.1.0 which is incompatible.
# ERROR: awscli 1.18.104 has requirement botocore==1.17.27, but you'll have botocore 1.17.31 which is incompatible.
# ERROR: astroid 2.3.3 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.
# ERROR: arize 0.0.20 has requirement protobuf==3.11.3, but you'll have protobuf 3.11.4 which is incompatible.
# Installing collected packages: jmespath, docutils, six, python-dateutil, urllib3, botocore, s3transfer, boto3
# Successfully installed boto3-1.14.31 botocore-1.17.31 docutils-0.15.2 jmespath-0.10.0 python-dateutil-2.8.1 s3transfer-0.3.3 six-1.15.0 urllib3-1.25.10
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/boto3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six-1.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/boto3-1.14.31.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/jmespath-0.10.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/botocore-1.17.31.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/s3transfer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/botocore already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/s3transfer-0.3.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/docutils-0.15.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/python_dateutil-2.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/docutils already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/jmespath already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3-1.25.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting s3fs
#   Using cached s3fs-0.4.2-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Using cached fsspec-0.7.4-py3-none-any.whl (75 kB)
# Collecting botocore>=1.12.91
#   Using cached botocore-1.17.31-py2.py3-none-any.whl (6.4 MB)
# Collecting urllib3<1.26,>=1.20; python_version != "3.4"
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting python-dateutil<3.0.0,>=2.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting docutils<0.16,>=0.10
#   Using cached docutils-0.15.2-py3-none-any.whl (547 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting six>=1.5
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: jupyterlab 1.2.6 has requirement jupyterlab_server~=1.0.0, but you'll have jupyterlab-server 1.1.0 which is incompatible.
# ERROR: awscli 1.18.104 has requirement botocore==1.17.27, but you'll have botocore 1.17.31 which is incompatible.
# ERROR: astroid 2.3.3 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.
# ERROR: arize 0.0.20 has requirement protobuf==3.11.3, but you'll have protobuf 3.11.4 which is incompatible.
# Installing collected packages: fsspec, urllib3, six, python-dateutil, docutils, jmespath, botocore, s3fs
# Successfully installed botocore-1.17.31 docutils-0.15.2 fsspec-0.7.4 jmespath-0.10.0 python-dateutil-2.8.1 s3fs-0.4.2 six-1.15.0 urllib3-1.25.10
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six-1.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/jmespath-0.10.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/botocore-1.17.31.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/s3fs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/botocore already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/docutils-0.15.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/fsspec-0.7.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/python_dateutil-2.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/fsspec already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/s3fs-0.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/docutils already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/jmespath already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/urllib3-1.25.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting datetime
#   Using cached DateTime-4.3-py2.py3-none-any.whl (60 kB)
# Collecting pytz
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting zope.interface
#   Using cached zope.interface-5.1.0-cp36-cp36m-manylinux2010_x86_64.whl (234 kB)
# Collecting setuptools
#   Using cached setuptools-49.2.0-py3-none-any.whl (789 kB)
# ERROR: arize 0.0.20 has requirement protobuf==3.11.3, but you'll have protobuf 3.11.4 which is incompatible.
# Installing collected packages: pytz, setuptools, zope.interface, datetime
# Successfully installed datetime-4.3 pytz-2020.1 setuptools-49.2.0 zope.interface-5.1.0
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pytz-2020.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/zope already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/setuptools-49.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/easy_install.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/zope.interface-5.1.0-py3.6-nspkg.pth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/DateTime already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/zope.interface-5.1.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/setuptools already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/DateTime-4.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pkg_resources already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/pytz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda_pkg/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# /home/ec2-user/SageMaker/lambda_pkg
# updating: arize/ (stored 0%)
# updating: arize/bounded_executor.py (deflated 60%)
# updating: arize/public_pb2.py (deflated 88%)
# updating: arize/__pycache__/ (stored 0%)
# updating: arize/__pycache__/__init__.cpython-36.pyc (deflated 12%)
# updating: arize/__pycache__/protocol_pb2.cpython-36.pyc (deflated 66%)
# updating: arize/__pycache__/public_pb2.cpython-36.pyc (deflated 64%)
# updating: arize/__pycache__/bounded_executor.cpython-36.pyc (deflated 43%)
# updating: arize/__pycache__/validation_helper.cpython-36.pyc (deflated 57%)
# updating: arize/__pycache__/input_transformer.cpython-36.pyc (deflated 50%)
# updating: arize/__pycache__/api.cpython-36.pyc (deflated 55%)
# updating: arize/input_transformer.py (deflated 71%)
# updating: arize/api.py (deflated 78%)
# updating: arize/__init__.py (stored 0%)
# updating: arize/validation_helper.py (deflated 82%)
# updating: arize/protocol_pb2.py (deflated 91%)
# updating: arize-0.0.20.dist-info/ (stored 0%)
# updating: arize-0.0.20.dist-info/INSTALLER (stored 0%)
# updating: arize-0.0.20.dist-info/RECORD (deflated 49%)
# updating: arize-0.0.20.dist-info/LICENSE.md (deflated 49%)
# updating: arize-0.0.20.dist-info/top_level.txt (stored 0%)
# updating: arize-0.0.20.dist-info/METADATA (deflated 58%)
# updating: arize-0.0.20.dist-info/WHEEL (deflated 14%)
# updating: bin/ (stored 0%)
# updating: bin/f2py (deflated 27%)
# updating: bin/chardetect (deflated 28%)
# updating: bin/f2py3 (deflated 27%)
# updating: bin/f2py3.6 (deflated 27%)
# updating: bin/easy_install (deflated 26%)
# updating: bin/easy_install-3.6 (deflated 26%)
# updating: certifi/ (stored 0%)
# updating: certifi/__pycache__/ (stored 0%)
# updating: certifi/__pycache__/__init__.cpython-36.pyc (deflated 11%)
# updating: certifi/__pycache__/core.cpython-36.pyc (deflated 39%)
# updating: certifi/__pycache__/__main__.cpython-36.pyc (deflated 24%)
# updating: certifi/__main__.py (deflated 39%)
# updating: certifi/core.py (deflated 57%)
# updating: certifi/__init__.py (stored 0%)
# updating: certifi/cacert.pem (deflated 46%)
# updating: certifi-2020.6.20.dist-info/ (stored 0%)
# updating: certifi-2020.6.20.dist-info/INSTALLER (stored 0%)
# updating: certifi-2020.6.20.dist-info/RECORD (deflated 44%)
# updating: certifi-2020.6.20.dist-info/top_level.txt (stored 0%)
# updating: certifi-2020.6.20.dist-info/METADATA (deflated 58%)
# updating: certifi-2020.6.20.dist-info/WHEEL (deflated 14%)
# updating: certifi-2020.6.20.dist-info/LICENSE (deflated 43%)
# updating: chardet/ (stored 0%)
# updating: chardet/langcyrillicmodel.py (deflated 83%)
# updating: chardet/chardistribution.py (deflated 75%)
# updating: chardet/langhungarianmodel.py (deflated 78%)
# updating: chardet/mbcssm.py (deflated 87%)
# updating: chardet/gb2312freq.py (deflated 51%)
# updating: chardet/jpcntx.py (deflated 75%)
# updating: chardet/charsetgroupprober.py (deflated 70%)
# updating: chardet/__pycache__/ (stored 0%)
# updating: chardet/__pycache__/__init__.cpython-36.pyc (deflated 33%)
# updating: chardet/__pycache__/euckrprober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/langthaimodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/escsm.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/version.cpython-36.pyc (deflated 21%)
# updating: chardet/__pycache__/compat.cpython-36.pyc (deflated 18%)
# updating: chardet/__pycache__/mbcssm.cpython-36.pyc (deflated 91%)
# updating: chardet/__pycache__/big5freq.cpython-36.pyc (deflated 53%)
# updating: chardet/__pycache__/langturkishmodel.cpython-36.pyc (deflated 88%)
# updating: chardet/__pycache__/euctwprober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/eucjpprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/mbcsgroupprober.cpython-36.pyc (deflated 41%)
# updating: chardet/__pycache__/sjisprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/utf8prober.cpython-36.pyc (deflated 43%)
# updating: chardet/__pycache__/sbcharsetprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/jpcntx.cpython-36.pyc (deflated 86%)
# updating: chardet/__pycache__/charsetgroupprober.cpython-36.pyc (deflated 46%)
# updating: chardet/__pycache__/mbcharsetprober.cpython-36.pyc (deflated 46%)
# updating: chardet/__pycache__/codingstatemachine.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/escprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/jisfreq.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/langhebrewmodel.cpython-36.pyc (deflated 90%)
# updating: chardet/__pycache__/langhungarianmodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/enums.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/euctwfreq.cpython-36.pyc (deflated 53%)
# updating: chardet/__pycache__/gb2312prober.cpython-36.pyc (deflated 43%)
# updating: chardet/__pycache__/charsetprober.cpython-36.pyc (deflated 50%)
# updating: chardet/__pycache__/sbcsgroupprober.cpython-36.pyc (deflated 44%)
# updating: chardet/__pycache__/euckrfreq.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/langbulgarianmodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/cp949prober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/chardistribution.cpython-36.pyc (deflated 66%)
# updating: chardet/__pycache__/universaldetector.cpython-36.pyc (deflated 47%)
# updating: chardet/__pycache__/langgreekmodel.cpython-36.pyc (deflated 91%)
# updating: chardet/__pycache__/big5prober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/hebrewprober.cpython-36.pyc (deflated 48%)
# updating: chardet/__pycache__/gb2312freq.cpython-36.pyc (deflated 51%)
# updating: chardet/__pycache__/langcyrillicmodel.cpython-36.pyc (deflated 90%)
# updating: chardet/__pycache__/latin1prober.cpython-36.pyc (deflated 58%)
# updating: chardet/escsm.py (deflated 85%)
# updating: chardet/euckrprober.py (deflated 53%)
# updating: chardet/euctwfreq.py (deflated 53%)
# updating: chardet/mbcsgroupprober.py (deflated 56%)
# updating: chardet/version.py (deflated 24%)
# updating: chardet/enums.py (deflated 58%)
# updating: chardet/sbcharsetprober.py (deflated 66%)
# updating: chardet/big5freq.py (deflated 53%)
# updating: chardet/sjisprober.py (deflated 65%)
# updating: chardet/universaldetector.py (deflated 72%)
# updating: chardet/langhebrewmodel.py (deflated 78%)
# updating: chardet/sbcsgroupprober.py (deflated 67%)
# updating: chardet/escprober.py (deflated 66%)
# updating: chardet/langgreekmodel.py (deflated 81%)
# updating: chardet/eucjpprober.py (deflated 65%)
# updating: chardet/euckrfreq.py (deflated 54%)
# updating: chardet/cli/ (stored 0%)
# updating: chardet/cli/__pycache__/ (stored 0%)
# updating: chardet/cli/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: chardet/cli/__pycache__/chardetect.cpython-36.pyc (deflated 49%)
# updating: chardet/cli/chardetect.py (deflated 57%)
# updating: chardet/cli/__init__.py (stored 0%)
# updating: chardet/jisfreq.py (deflated 52%)
# updating: chardet/latin1prober.py (deflated 69%)
# updating: chardet/compat.py (deflated 48%)
# updating: chardet/hebrewprober.py (deflated 66%)
# updating: chardet/codingstatemachine.py (deflated 60%)
# updating: chardet/gb2312prober.py (deflated 53%)
# updating: chardet/langturkishmodel.py (deflated 75%)
# updating: chardet/big5prober.py (deflated 53%)
# updating: chardet/mbcharsetprober.py (deflated 64%)
# updating: chardet/__init__.py (deflated 53%)
# updating: chardet/cp949prober.py (deflated 53%)
# updating: chardet/euctwprober.py (deflated 53%)
# updating: chardet/langbulgarianmodel.py (deflated 78%)
# updating: chardet/utf8prober.py (deflated 60%)
# updating: chardet/langthaimodel.py (deflated 75%)
# updating: chardet/charsetprober.py (deflated 61%)
# updating: chardet-3.0.4.dist-info/ (stored 0%)
# updating: chardet-3.0.4.dist-info/INSTALLER (stored 0%)
# updating: chardet-3.0.4.dist-info/RECORD (deflated 59%)
# updating: chardet-3.0.4.dist-info/metadata.json (deflated 57%)
# updating: chardet-3.0.4.dist-info/DESCRIPTION.rst (deflated 53%)
# updating: chardet-3.0.4.dist-info/entry_points.txt (deflated 20%)
# updating: chardet-3.0.4.dist-info/top_level.txt (stored 0%)
# updating: chardet-3.0.4.dist-info/METADATA (deflated 58%)
# updating: chardet-3.0.4.dist-info/WHEEL (deflated 14%)
# updating: dateutil/ (stored 0%)
# updating: dateutil/rrule.py (deflated 77%)
# updating: dateutil/utils.py (deflated 58%)
# updating: dateutil/easter.py (deflated 53%)
# updating: dateutil/__pycache__/ (stored 0%)
# updating: dateutil/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: dateutil/__pycache__/rrule.cpython-36.pyc (deflated 57%)
# updating: dateutil/__pycache__/_version.cpython-36.pyc (deflated 16%)
# updating: dateutil/__pycache__/easter.cpython-36.pyc (deflated 41%)
# updating: dateutil/__pycache__/relativedelta.cpython-36.pyc (deflated 59%)
# updating: dateutil/__pycache__/utils.cpython-36.pyc (deflated 49%)
# updating: dateutil/__pycache__/_common.cpython-36.pyc (deflated 46%)
# updating: dateutil/__pycache__/tzwin.cpython-36.pyc (deflated 13%)
# updating: dateutil/parser/ (stored 0%)
# updating: dateutil/parser/isoparser.py (deflated 71%)
# updating: dateutil/parser/__pycache__/ (stored 0%)
# updating: dateutil/parser/__pycache__/__init__.cpython-36.pyc (deflated 46%)
# updating: dateutil/parser/__pycache__/isoparser.cpython-36.pyc (deflated 55%)
# updating: dateutil/parser/__pycache__/_parser.cpython-36.pyc (deflated 59%)
# updating: dateutil/parser/__init__.py (deflated 66%)
# updating: dateutil/parser/_parser.py (deflated 76%)
# updating: dateutil/tzwin.py (deflated 8%)
# updating: dateutil/_common.py (deflated 61%)
# updating: dateutil/_version.py (deflated 13%)
# updating: dateutil/relativedelta.py (deflated 77%)
# updating: dateutil/zoneinfo/ (stored 0%)
# updating: dateutil/zoneinfo/__pycache__/ (stored 0%)
# updating: dateutil/zoneinfo/__pycache__/__init__.cpython-36.pyc (deflated 54%)
# updating: dateutil/zoneinfo/__pycache__/rebuild.cpython-36.pyc (deflated 34%)
# updating: dateutil/zoneinfo/rebuild.py (deflated 56%)
# updating: dateutil/zoneinfo/dateutil-zoneinfo.tar.gz (deflated 3%)
# updating: dateutil/zoneinfo/__init__.py (deflated 65%)
# updating: dateutil/tz/ (stored 0%)
# updating: dateutil/tz/__pycache__/ (stored 0%)
# updating: dateutil/tz/__pycache__/__init__.cpython-36.pyc (deflated 30%)
# updating: dateutil/tz/__pycache__/_factories.cpython-36.pyc (deflated 55%)
# updating: dateutil/tz/__pycache__/win.cpython-36.pyc (deflated 53%)
# updating: dateutil/tz/__pycache__/_common.cpython-36.pyc (deflated 62%)
# updating: dateutil/tz/__pycache__/tz.cpython-36.pyc (deflated 60%)
# updating: dateutil/tz/_factories.py (deflated 76%)
# updating: dateutil/tz/win.py (deflated 69%)
# updating: dateutil/tz/_common.py (deflated 74%)
# updating: dateutil/tz/tz.py (deflated 75%)
# updating: dateutil/tz/__init__.py (deflated 46%)
# updating: dateutil/__init__.py (deflated 32%)
# updating: easy_install.py (deflated 17%)
# updating: google/ (stored 0%)
# updating: google/longrunning/ (stored 0%)
# updating: google/longrunning/operations_proto.py (deflated 28%)
# updating: google/longrunning/__pycache__/ (stored 0%)
# updating: google/longrunning/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/longrunning/__pycache__/operations_proto_pb2.cpython-36.pyc (deflated 66%)
# updating: google/longrunning/__pycache__/operations_proto.cpython-36.pyc (deflated 20%)
# updating: google/longrunning/__pycache__/operations_grpc_pb2.cpython-36.pyc (deflated 50%)
# updating: google/longrunning/__pycache__/operations_pb2.cpython-36.pyc (deflated 34%)
# updating: google/longrunning/__pycache__/operations_grpc.cpython-36.pyc (deflated 20%)
# updating: google/longrunning/operations_grpc_pb2.py (deflated 67%)
# updating: google/longrunning/operations_pb2.py (deflated 50%)
# updating: google/longrunning/operations_proto_pb2.py (deflated 86%)
# updating: google/longrunning/operations_grpc.py (deflated 28%)
# updating: google/longrunning/__init__.py (stored 0%)
# updating: google/rpc/ (stored 0%)
# updating: google/rpc/__pycache__/ (stored 0%)
# updating: google/rpc/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: google/rpc/__pycache__/error_details_pb2.cpython-36.pyc (deflated 67%)
# updating: google/rpc/__pycache__/status_pb2.cpython-36.pyc (deflated 47%)
# updating: google/rpc/__pycache__/code_pb2.cpython-36.pyc (deflated 49%)
# updating: google/rpc/status_pb2.py (deflated 68%)
# updating: google/rpc/error_details_pb2.py (deflated 89%)
# updating: google/rpc/__init__.py (stored 0%)
# updating: google/rpc/code_pb2.py (deflated 73%)
# updating: google/api/ (stored 0%)
# updating: google/api/httpbody_pb2.py (deflated 68%)
# updating: google/api/system_parameter_pb2.py (deflated 81%)
# updating: google/api/context_pb2.py (deflated 77%)
# updating: google/api/auth_pb2.py (deflated 85%)
# updating: google/api/distribution_pb2.py (deflated 88%)
# updating: google/api/label_pb2.py (deflated 72%)
# updating: google/api/http_pb2.py (deflated 84%)
# updating: google/api/control_pb2.py (deflated 61%)
# updating: google/api/__pycache__/ (stored 0%)
# updating: google/api/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: google/api/__pycache__/log_pb2.cpython-36.pyc (deflated 50%)
# updating: google/api/__pycache__/endpoint_pb2.cpython-36.pyc (deflated 49%)
# updating: google/api/__pycache__/system_parameter_pb2.cpython-36.pyc (deflated 57%)
# updating: google/api/__pycache__/field_behavior_pb2.cpython-36.pyc (deflated 49%)
# updating: google/api/__pycache__/monitoring_pb2.cpython-36.pyc (deflated 54%)
# updating: google/api/__pycache__/client_pb2.cpython-36.pyc (deflated 48%)
# updating: google/api/__pycache__/quota_pb2.cpython-36.pyc (deflated 62%)
# updating: google/api/__pycache__/label_pb2.cpython-36.pyc (deflated 50%)
# updating: google/api/__pycache__/service_pb2.cpython-36.pyc (deflated 64%)
# updating: google/api/__pycache__/source_info_pb2.cpython-36.pyc (deflated 47%)
# updating: google/api/__pycache__/distribution_pb2.cpython-36.pyc (deflated 66%)
# updating: google/api/__pycache__/auth_pb2.cpython-36.pyc (deflated 61%)
# updating: google/api/__pycache__/metric_pb2.cpython-36.pyc (deflated 62%)
# updating: google/api/__pycache__/documentation_pb2.cpython-36.pyc (deflated 59%)
# updating: google/api/__pycache__/launch_stage_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/control_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/consumer_pb2.cpython-36.pyc (deflated 52%)
# updating: google/api/__pycache__/usage_pb2.cpython-36.pyc (deflated 52%)
# updating: google/api/__pycache__/config_change_pb2.cpython-36.pyc (deflated 53%)
# updating: google/api/__pycache__/annotations_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/http_pb2.cpython-36.pyc (deflated 60%)
# updating: google/api/__pycache__/httpbody_pb2.cpython-36.pyc (deflated 47%)
# updating: google/api/__pycache__/backend_pb2.cpython-36.pyc (deflated 55%)
# updating: google/api/__pycache__/monitored_resource_pb2.cpython-36.pyc (deflated 63%)
# updating: google/api/__pycache__/resource_pb2.cpython-36.pyc (deflated 56%)
# updating: google/api/__pycache__/billing_pb2.cpython-36.pyc (deflated 51%)
# updating: google/api/__pycache__/logging_pb2.cpython-36.pyc (deflated 53%)
# updating: google/api/__pycache__/context_pb2.cpython-36.pyc (deflated 54%)
# updating: google/api/usage_pb2.py (deflated 76%)
# updating: google/api/launch_stage_pb2.py (deflated 66%)
# updating: google/api/quota_pb2.py (deflated 86%)
# updating: google/api/documentation_pb2.py (deflated 83%)
# updating: google/api/backend_pb2.py (deflated 79%)
# updating: google/api/source_info_pb2.py (deflated 63%)
# updating: google/api/resource_pb2.py (deflated 79%)
# updating: google/api/consumer_pb2.py (deflated 76%)
# updating: google/api/field_behavior_pb2.py (deflated 68%)
# updating: google/api/annotations_pb2.py (deflated 60%)
# updating: google/api/config_change_pb2.py (deflated 77%)
# updating: google/api/metric_pb2.py (deflated 85%)
# updating: google/api/__init__.py (stored 0%)
# updating: google/api/monitoring_pb2.py (deflated 76%)
# updating: google/api/client_pb2.py (deflated 69%)
# updating: google/api/log_pb2.py (deflated 72%)
# updating: google/api/monitored_resource_pb2.py (deflated 86%)
# updating: google/api/billing_pb2.py (deflated 73%)
# updating: google/api/logging_pb2.py (deflated 76%)
# updating: google/api/service_pb2.py (deflated 85%)
# updating: google/api/endpoint_pb2.py (deflated 73%)
# updating: google/logging/ (stored 0%)
# updating: google/logging/type/ (stored 0%)
# updating: google/logging/type/__pycache__/ (stored 0%)
# updating: google/logging/type/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/logging/type/__pycache__/log_severity_pb2.cpython-36.pyc (deflated 46%)
# updating: google/logging/type/__pycache__/http_request_pb2.cpython-36.pyc (deflated 59%)
# updating: google/logging/type/log_severity_pb2.py (deflated 68%)
# updating: google/logging/type/http_request_pb2.py (deflated 82%)
# updating: google/logging/type/__init__.py (stored 0%)
# updating: google/type/ (stored 0%)
# updating: google/type/color_pb2.py (deflated 71%)
# updating: google/type/postal_address_pb2.py (deflated 81%)
# updating: google/type/dayofweek_pb2.py (deflated 69%)
# updating: google/type/__pycache__/ (stored 0%)
# updating: google/type/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: google/type/__pycache__/fraction_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/quaternion_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/latlng_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/timeofday_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/money_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/date_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/calendar_period_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/expr_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/dayofweek_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/postal_address_pb2.cpython-36.pyc (deflated 59%)
# updating: google/type/__pycache__/color_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/expr_pb2.py (deflated 72%)
# updating: google/type/calendar_period_pb2.py (deflated 69%)
# updating: google/type/date_pb2.py (deflated 69%)
# updating: google/type/fraction_pb2.py (deflated 66%)
# updating: google/type/latlng_pb2.py (deflated 66%)
# updating: google/type/__init__.py (stored 0%)
# updating: google/type/timeofday_pb2.py (deflated 72%)
# updating: google/type/quaternion_pb2.py (deflated 73%)
# updating: google/type/money_pb2.py (deflated 68%)
# updating: google/protobuf/ (stored 0%)
# updating: google/protobuf/unittest_no_generic_services_pb2.py (deflated 72%)
# updating: google/protobuf/struct_pb2.py (deflated 83%)
# updating: google/protobuf/test_messages_proto3_pb2.py (deflated 93%)
# updating: google/protobuf/source_context_pb2.py (deflated 63%)
# updating: google/protobuf/unittest_proto3_arena_pb2.py (deflated 91%)
# updating: google/protobuf/unittest_arena_pb2.py (deflated 76%)
# updating: google/protobuf/message.py (deflated 65%)
# updating: google/protobuf/descriptor_database.py (deflated 64%)
# updating: google/protobuf/type_pb2.py (deflated 87%)
# updating: google/protobuf/symbol_database.py (deflated 65%)
# updating: google/protobuf/compiler/ (stored 0%)
# updating: google/protobuf/compiler/__pycache__/ (stored 0%)
# updating: google/protobuf/compiler/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/protobuf/compiler/__pycache__/plugin_pb2.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/compiler/plugin_pb2.py (deflated 85%)
# updating: google/protobuf/compiler/__init__.py (stored 0%)
# updating: google/protobuf/unittest_no_arena_import_pb2.py (deflated 66%)
# updating: google/protobuf/service_reflection.py (deflated 72%)
# updating: google/protobuf/__pycache__/ (stored 0%)
# updating: google/protobuf/__pycache__/unittest_proto3_arena_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: google/protobuf/__pycache__/unittest_no_generic_services_pb2.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/__pycache__/text_format.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/__pycache__/descriptor_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/descriptor.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/__pycache__/service.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/__pycache__/text_encoding.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/__pycache__/unittest_import_public_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/unittest_import_pb2.cpython-36.pyc (deflated 52%)
# updating: google/protobuf/__pycache__/message_factory.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/proto_builder.cpython-36.pyc (deflated 44%)
# updating: google/protobuf/__pycache__/test_messages_proto3_pb2.cpython-36.pyc (deflated 80%)
# updating: google/protobuf/__pycache__/unittest_pb2.cpython-36.pyc (deflated 79%)
# updating: google/protobuf/__pycache__/map_proto2_unittest_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/source_context_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/unittest_custom_options_pb2.cpython-36.pyc (deflated 70%)
# updating: google/protobuf/__pycache__/any_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/any_test_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/struct_pb2.cpython-36.pyc (deflated 59%)
# updating: google/protobuf/__pycache__/duration_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/json_format.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/__pycache__/unittest_mset_pb2.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/__pycache__/symbol_database.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/__pycache__/test_messages_proto2_pb2.cpython-36.pyc (deflated 80%)
# updating: google/protobuf/__pycache__/type_pb2.cpython-36.pyc (deflated 65%)
# updating: google/protobuf/__pycache__/message.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/__pycache__/map_unittest_pb2.cpython-36.pyc (deflated 81%)
# updating: google/protobuf/__pycache__/unittest_no_arena_import_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/service_reflection.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/__pycache__/timestamp_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/reflection.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/api_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/__pycache__/wrappers_pb2.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/__pycache__/unittest_no_arena_pb2.cpython-36.pyc (deflated 74%)
# updating: google/protobuf/__pycache__/unittest_mset_wire_format_pb2.cpython-36.pyc (deflated 51%)
# updating: google/protobuf/__pycache__/descriptor_database.cpython-36.pyc (deflated 56%)
# updating: google/protobuf/__pycache__/empty_pb2.cpython-36.pyc (deflated 46%)
# updating: google/protobuf/__pycache__/field_mask_pb2.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/__pycache__/descriptor_pool.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/__pycache__/unittest_arena_pb2.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/unittest_import_public_pb2.py (deflated 65%)
# updating: google/protobuf/json_format.py (deflated 77%)
# updating: google/protobuf/wrappers_pb2.py (deflated 87%)
# updating: google/protobuf/descriptor_pb2.py (deflated 91%)
# updating: google/protobuf/internal/ (stored 0%)
# updating: google/protobuf/internal/extension_dict.py (deflated 65%)
# updating: google/protobuf/internal/test_bad_identifiers_pb2.py (deflated 77%)
# updating: google/protobuf/internal/_parameterized.py (deflated 66%)
# updating: google/protobuf/internal/json_format_test.py (deflated 82%)
# updating: google/protobuf/internal/_api_implementation.cpython-36m-x86_64-linux-gnu.so (deflated 64%)
# updating: google/protobuf/internal/proto_builder_test.py (deflated 61%)
# updating: google/protobuf/internal/message_test.py (deflated 82%)
# updating: google/protobuf/internal/testing_refleaks.py (deflated 57%)
# updating: google/protobuf/internal/encoder.py (deflated 79%)
# updating: google/protobuf/internal/message_factory_test.py (deflated 72%)
# updating: google/protobuf/internal/message_listener.py (deflated 52%)
# updating: google/protobuf/internal/factory_test1_pb2.py (deflated 84%)
# updating: google/protobuf/internal/__pycache__/ (stored 0%)
# updating: google/protobuf/internal/__pycache__/test_util.cpython-36.pyc (deflated 69%)
# updating: google/protobuf/internal/__pycache__/message_factory_test.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/internal/__pycache__/__init__.cpython-36.pyc (deflated 17%)
# updating: google/protobuf/internal/__pycache__/encoder.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/decoder.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test1_pb2.cpython-36.pyc (deflated 73%)
# updating: google/protobuf/internal/__pycache__/symbol_database_test.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/wire_format_test.cpython-36.pyc (deflated 59%)
# updating: google/protobuf/internal/__pycache__/json_format_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/test_bad_identifiers_pb2.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/internal/__pycache__/descriptor_database_test.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/message_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/api_implementation.cpython-36.pyc (deflated 45%)
# updating: google/protobuf/internal/__pycache__/missing_enum_values_pb2.cpython-36.pyc (deflated 65%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test2_pb2.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/descriptor_test.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/internal/__pycache__/enum_type_wrapper.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/python_message.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/internal/__pycache__/any_test_pb2.cpython-36.pyc (deflated 56%)
# updating: google/protobuf/internal/__pycache__/_parameterized.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/reflection_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/text_encoding_test.cpython-36.pyc (deflated 42%)
# updating: google/protobuf/internal/__pycache__/unknown_fields_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/keywords_test.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/proto_builder_test.cpython-36.pyc (deflated 50%)
# updating: google/protobuf/internal/__pycache__/packed_field_test_pb2.cpython-36.pyc (deflated 73%)
# updating: google/protobuf/internal/__pycache__/more_extensions_dynamic_pb2.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/containers.cpython-36.pyc (deflated 68%)
# updating: google/protobuf/internal/__pycache__/well_known_types.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/service_reflection_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/file_options_test_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/internal/__pycache__/extension_dict.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/well_known_types_test.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/text_format_test.cpython-36.pyc (deflated 72%)
# updating: google/protobuf/internal/__pycache__/type_checkers.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/internal/__pycache__/generator_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/message_listener.cpython-36.pyc (deflated 51%)
# updating: google/protobuf/internal/__pycache__/factory_test1_pb2.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/internal/__pycache__/more_extensions_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/internal/__pycache__/factory_test2_pb2.cpython-36.pyc (deflated 70%)
# updating: google/protobuf/internal/__pycache__/message_set_extensions_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/internal/__pycache__/more_messages_pb2.cpython-36.pyc (deflated 82%)
# updating: google/protobuf/internal/__pycache__/no_package_pb2.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/internal/__pycache__/wire_format.cpython-36.pyc (deflated 57%)
# updating: google/protobuf/internal/__pycache__/testing_refleaks.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/internal/more_extensions_dynamic_pb2.py (deflated 77%)
# updating: google/protobuf/internal/no_package_pb2.py (deflated 68%)
# updating: google/protobuf/internal/api_implementation.py (deflated 61%)
# updating: google/protobuf/internal/descriptor_pool_test.py (deflated 84%)
# updating: google/protobuf/internal/wire_format_test.py (deflated 75%)
# updating: google/protobuf/internal/well_known_types_test.py (deflated 81%)
# updating: google/protobuf/internal/symbol_database_test.py (deflated 70%)
# updating: google/protobuf/internal/test_util.py (deflated 83%)
# ...
# updating: s3transfer-0.3.3.dist-info/top_level.txt (stored 0%)
# updating: s3transfer-0.3.3.dist-info/METADATA (deflated 57%)
# updating: s3transfer-0.3.3.dist-info/WHEEL (deflated 14%)
# updating: fsspec/ (stored 0%)
# updating: fsspec/compression.py (deflated 65%)
# updating: fsspec/caching.py (deflated 73%)
# updating: fsspec/utils.py (deflated 64%)
# updating: fsspec/__pycache__/ (stored 0%)
# updating: fsspec/__pycache__/caching.cpython-36.pyc (deflated 55%)
# updating: fsspec/__pycache__/__init__.cpython-36.pyc (deflated 34%)
# updating: fsspec/__pycache__/_version.cpython-36.pyc (deflated 27%)
# updating: fsspec/__pycache__/compression.cpython-36.pyc (deflated 47%)
# updating: fsspec/__pycache__/mapping.cpython-36.pyc (deflated 51%)
# updating: fsspec/__pycache__/dircache.cpython-36.pyc (deflated 52%)
# updating: fsspec/__pycache__/fuse.cpython-36.pyc (deflated 52%)
# updating: fsspec/__pycache__/spec.cpython-36.pyc (deflated 60%)
# updating: fsspec/__pycache__/registry.cpython-36.pyc (deflated 55%)
# updating: fsspec/__pycache__/transaction.cpython-36.pyc (deflated 56%)
# updating: fsspec/__pycache__/conftest.cpython-36.pyc (deflated 36%)
# updating: fsspec/__pycache__/utils.cpython-36.pyc (deflated 51%)
# updating: fsspec/__pycache__/core.cpython-36.pyc (deflated 57%)
# updating: fsspec/__pycache__/gui.cpython-36.pyc (deflated 54%)
# updating: fsspec/registry.py (deflated 70%)
# updating: fsspec/transaction.py (deflated 69%)
# updating: fsspec/spec.py (deflated 72%)
# updating: fsspec/mapping.py (deflated 64%)
# updating: fsspec/core.py (deflated 72%)
# updating: fsspec/_version.py (deflated 30%)
# updating: fsspec/conftest.py (deflated 57%)
# updating: fsspec/dircache.py (deflated 67%)
# updating: fsspec/implementations/ (stored 0%)
# updating: fsspec/implementations/dask.py (deflated 73%)
# updating: fsspec/implementations/hdfs.py (deflated 70%)
# updating: fsspec/implementations/git.py (deflated 69%)
# updating: fsspec/implementations/dvc.py (deflated 60%)
# updating: fsspec/implementations/__pycache__/ (stored 0%)
# updating: fsspec/implementations/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: fsspec/implementations/__pycache__/ftp.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/dvc.cpython-36.pyc (deflated 42%)
# updating: fsspec/implementations/__pycache__/cached.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/zip.cpython-36.pyc (deflated 46%)
# updating: fsspec/implementations/__pycache__/hdfs.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/webhdfs.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/memory.cpython-36.pyc (deflated 50%)
# updating: fsspec/implementations/__pycache__/git.cpython-36.pyc (deflated 44%)
# updating: fsspec/implementations/__pycache__/sftp.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/dask.cpython-36.pyc (deflated 54%)
# updating: fsspec/implementations/__pycache__/local.cpython-36.pyc (deflated 54%)
# updating: fsspec/implementations/__pycache__/github.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/http.cpython-36.pyc (deflated 49%)
# updating: fsspec/implementations/local.py (deflated 70%)
# updating: fsspec/implementations/ftp.py (deflated 70%)
# updating: fsspec/implementations/zip.py (deflated 66%)
# updating: fsspec/implementations/memory.py (deflated 72%)
# updating: fsspec/implementations/webhdfs.py (deflated 69%)
# updating: fsspec/implementations/cached.py (deflated 75%)
# updating: fsspec/implementations/http.py (deflated 68%)
# updating: fsspec/implementations/github.py (deflated 67%)
# updating: fsspec/implementations/sftp.py (deflated 65%)
# updating: fsspec/implementations/__init__.py (stored 0%)
# updating: fsspec/fuse.py (deflated 67%)
# updating: fsspec/__init__.py (deflated 60%)
# updating: fsspec/gui.py (deflated 69%)
# updating: fsspec-0.7.4.dist-info/ (stored 0%)
# updating: fsspec-0.7.4.dist-info/INSTALLER (stored 0%)
# updating: fsspec-0.7.4.dist-info/RECORD (deflated 59%)
# updating: fsspec-0.7.4.dist-info/top_level.txt (stored 0%)
# updating: fsspec-0.7.4.dist-info/METADATA (deflated 58%)
# updating: fsspec-0.7.4.dist-info/WHEEL (stored 0%)
# updating: fsspec-0.7.4.dist-info/LICENSE (deflated 48%)
# updating: s3fs/ (stored 0%)
# updating: s3fs/errors.py (deflated 75%)
# updating: s3fs/utils.py (deflated 60%)
# updating: s3fs/__pycache__/ (stored 0%)
# updating: s3fs/__pycache__/__init__.cpython-36.pyc (deflated 21%)
# updating: s3fs/__pycache__/_version.cpython-36.pyc (deflated 26%)
# updating: s3fs/__pycache__/mapping.cpython-36.pyc (deflated 22%)
# updating: s3fs/__pycache__/errors.cpython-36.pyc (deflated 53%)
# updating: s3fs/__pycache__/utils.cpython-36.pyc (deflated 49%)
# updating: s3fs/__pycache__/core.cpython-36.pyc (deflated 57%)
# updating: s3fs/mapping.py (deflated 32%)
# updating: s3fs/core.py (deflated 75%)
# updating: s3fs/_version.py (deflated 30%)
# updating: s3fs/__init__.py (deflated 41%)
# updating: s3fs-0.4.2.dist-info/ (stored 0%)
# updating: s3fs-0.4.2.dist-info/INSTALLER (stored 0%)
# updating: s3fs-0.4.2.dist-info/RECORD (deflated 46%)
# updating: s3fs-0.4.2.dist-info/pbr.json (stored 0%)
# updating: s3fs-0.4.2.dist-info/LICENSE.txt (deflated 47%)
# updating: s3fs-0.4.2.dist-info/top_level.txt (stored 0%)
# updating: s3fs-0.4.2.dist-info/METADATA (deflated 56%)
# updating: s3fs-0.4.2.dist-info/WHEEL (stored 0%)
# updating: DateTime/ (stored 0%)
# updating: DateTime/pytz.txt (deflated 64%)
# updating: DateTime/__pycache__/ (stored 0%)
# updating: DateTime/__pycache__/__init__.cpython-36.pyc (deflated 22%)
# updating: DateTime/__pycache__/pytz_support.cpython-36.pyc (deflated 56%)
# updating: DateTime/__pycache__/DateTime.cpython-36.pyc (deflated 65%)
# updating: DateTime/__pycache__/interfaces.cpython-36.pyc (deflated 76%)
# updating: DateTime/DateTime.py (deflated 76%)
# updating: DateTime/tests/ (stored 0%)
# updating: DateTime/tests/__pycache__/ (stored 0%)
# updating: DateTime/tests/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: DateTime/tests/__pycache__/test_datetime.cpython-36.pyc (deflated 62%)
# updating: DateTime/tests/__init__.py (deflated 46%)
# updating: DateTime/tests/test_datetime.py (deflated 76%)
# updating: DateTime/tests/julian_testdata.txt (deflated 78%)
# updating: DateTime/interfaces.py (deflated 78%)
# updating: DateTime/__init__.py (deflated 47%)
# updating: DateTime/pytz_support.py (deflated 73%)
# updating: DateTime/DateTime.txt (deflated 72%)
# updating: DateTime-4.3.dist-info/ (stored 0%)
# updating: DateTime-4.3.dist-info/INSTALLER (stored 0%)
# updating: DateTime-4.3.dist-info/RECORD (deflated 48%)
# updating: DateTime-4.3.dist-info/metadata.json (deflated 55%)
# updating: DateTime-4.3.dist-info/DESCRIPTION.rst (deflated 70%)
# updating: DateTime-4.3.dist-info/top_level.txt (stored 0%)
# updating: DateTime-4.3.dist-info/METADATA (deflated 70%)
# updating: DateTime-4.3.dist-info/WHEEL (deflated 14%)
# updating: zope/ (stored 0%)
# updating: zope/interface/ (stored 0%)
# updating: zope/interface/_zope_interface_coptimizations.c (deflated 82%)
# updating: zope/interface/ro.py (deflated 67%)
# updating: zope/interface/declarations.py (deflated 74%)
# updating: zope/interface/_flatten.py (deflated 49%)
# updating: zope/interface/interface.py (deflated 71%)
# updating: zope/interface/__pycache__/ (stored 0%)
# updating: zope/interface/__pycache__/__init__.cpython-36.pyc (deflated 50%)
# updating: zope/interface/__pycache__/ro.cpython-36.pyc (deflated 57%)
# updating: zope/interface/__pycache__/advice.cpython-36.pyc (deflated 46%)
# updating: zope/interface/__pycache__/_compat.cpython-36.pyc (deflated 51%)
# updating: zope/interface/__pycache__/document.cpython-36.pyc (deflated 45%)
# updating: zope/interface/__pycache__/registry.cpython-36.pyc (deflated 66%)
# updating: zope/interface/__pycache__/verify.cpython-36.pyc (deflated 46%)
# updating: zope/interface/__pycache__/interfaces.cpython-36.pyc (deflated 78%)
# updating: zope/interface/__pycache__/exceptions.cpython-36.pyc (deflated 59%)
# updating: zope/interface/__pycache__/declarations.cpython-36.pyc (deflated 65%)
# updating: zope/interface/__pycache__/adapter.cpython-36.pyc (deflated 62%)
# updating: zope/interface/__pycache__/_flatten.cpython-36.pyc (deflated 27%)
# updating: zope/interface/__pycache__/interface.cpython-36.pyc (deflated 58%)
# updating: zope/interface/registry.py (deflated 81%)
# updating: zope/interface/common/ (stored 0%)
# updating: zope/interface/common/numbers.py (deflated 59%)
# updating: zope/interface/common/io.py (deflated 52%)
# updating: zope/interface/common/sequence.py (deflated 67%)
# updating: zope/interface/common/__pycache__/ (stored 0%)
# updating: zope/interface/common/__pycache__/__init__.cpython-36.pyc (deflated 56%)
# updating: zope/interface/common/__pycache__/numbers.cpython-36.pyc (deflated 57%)
# updating: zope/interface/common/__pycache__/mapping.cpython-36.pyc (deflated 65%)
# updating: zope/interface/common/__pycache__/interfaces.cpython-36.pyc (deflated 74%)
# updating: zope/interface/common/__pycache__/idatetime.cpython-36.pyc (deflated 72%)
# updating: zope/interface/common/__pycache__/sequence.cpython-36.pyc (deflated 67%)
# updating: zope/interface/common/__pycache__/io.cpython-36.pyc (deflated 46%)
# updating: zope/interface/common/__pycache__/collections.cpython-36.pyc (deflated 64%)
# updating: zope/interface/common/__pycache__/builtins.cpython-36.pyc (deflated 57%)
# updating: zope/interface/common/collections.py (deflated 69%)
# updating: zope/interface/common/builtins.py (deflated 62%)
# updating: zope/interface/common/mapping.py (deflated 65%)
# updating: zope/interface/common/idatetime.py (deflated 75%)
# updating: zope/interface/common/tests/ (stored 0%)
# updating: zope/interface/common/tests/test_collections.py (deflated 65%)
# updating: zope/interface/common/tests/test_builtins.py (deflated 56%)
# updating: zope/interface/common/tests/test_idatetime.py (deflated 61%)
# updating: zope/interface/common/tests/__pycache__/ (stored 0%)
# updating: zope/interface/common/tests/__pycache__/__init__.cpython-36.pyc (deflated 47%)
# updating: zope/interface/common/tests/__pycache__/test_builtins.cpython-36.pyc (deflated 40%)
# updating: zope/interface/common/tests/__pycache__/basemapping.cpython-36.pyc (deflated 66%)
# updating: zope/interface/common/tests/__pycache__/test_idatetime.cpython-36.pyc (deflated 45%)
# updating: zope/interface/common/tests/__pycache__/test_numbers.cpython-36.pyc (deflated 46%)
# updating: zope/interface/common/tests/__pycache__/test_io.cpython-36.pyc (deflated 53%)
# updating: zope/interface/common/tests/__pycache__/test_collections.cpython-36.pyc (deflated 60%)
# updating: zope/interface/common/tests/__pycache__/test_import_interfaces.cpython-36.pyc (deflated 41%)
# updating: zope/interface/common/tests/basemapping.py (deflated 76%)
# updating: zope/interface/common/tests/test_import_interfaces.py (deflated 46%)
# updating: zope/interface/common/tests/test_io.py (deflated 59%)
# updating: zope/interface/common/tests/test_numbers.py (deflated 56%)
# updating: zope/interface/common/tests/__init__.py (deflated 66%)
# updating: zope/interface/common/interfaces.py (deflated 77%)
# updating: zope/interface/common/__init__.py (deflated 65%)
# updating: zope/interface/tests/ (stored 0%)
# updating: zope/interface/tests/test_document.py (deflated 89%)
# updating: zope/interface/tests/test_verify.py (deflated 87%)
# updating: zope/interface/tests/test_sorting.py (deflated 62%)
# updating: zope/interface/tests/test_interfaces.py (deflated 86%)
# updating: zope/interface/tests/dummy.py (deflated 47%)
# updating: zope/interface/tests/__pycache__/ (stored 0%)
# updating: zope/interface/tests/__pycache__/__init__.cpython-36.pyc (deflated 50%)
# updating: zope/interface/tests/__pycache__/test_advice.cpython-36.pyc (deflated 72%)
# updating: zope/interface/tests/__pycache__/test_adapter.cpython-36.pyc (deflated 79%)
# updating: zope/interface/tests/__pycache__/test_ro.cpython-36.pyc (deflated 71%)
# updating: zope/interface/tests/__pycache__/advisory_testing.cpython-36.pyc (deflated 42%)
# updating: zope/interface/tests/__pycache__/odd.cpython-36.pyc (deflated 56%)
# updating: zope/interface/tests/__pycache__/test_element.cpython-36.pyc (deflated 39%)
# updating: zope/interface/tests/__pycache__/test_sorting.cpython-36.pyc (deflated 61%)
# updating: zope/interface/tests/__pycache__/test_document.cpython-36.pyc (deflated 85%)
# updating: zope/interface/tests/__pycache__/idummy.cpython-36.pyc (deflated 39%)
# updating: zope/interface/tests/__pycache__/test_interface.cpython-36.pyc (deflated 78%)
# updating: zope/interface/tests/__pycache__/test_odd_declarations.cpython-36.pyc (deflated 73%)
# updating: zope/interface/tests/__pycache__/test_exceptions.cpython-36.pyc (deflated 72%)
# updating: zope/interface/tests/__pycache__/m1.cpython-36.pyc (deflated 40%)
# updating: zope/interface/tests/__pycache__/dummy.cpython-36.pyc (deflated 29%)
# updating: zope/interface/tests/__pycache__/test_verify.cpython-36.pyc (deflated 84%)
# updating: zope/interface/tests/__pycache__/test_declarations.cpython-36.pyc (deflated 79%)
# updating: zope/interface/tests/__pycache__/test_interfaces.cpython-36.pyc (deflated 74%)
# updating: zope/interface/tests/__pycache__/test_registry.cpython-36.pyc (deflated 82%)
# updating: zope/interface/tests/test_element.py (deflated 51%)
# updating: zope/interface/tests/test_declarations.py (deflated 87%)
# updating: zope/interface/tests/test_adapter.py (deflated 90%)
# updating: zope/interface/tests/idummy.py (deflated 48%)
# updating: zope/interface/tests/advisory_testing.py (deflated 53%)
# updating: zope/interface/tests/test_advice.py (deflated 78%)
# updating: zope/interface/tests/test_interface.py (deflated 86%)
# updating: zope/interface/tests/m1.py (deflated 47%)
# updating: zope/interface/tests/test_odd_declarations.py (deflated 77%)
# updating: zope/interface/tests/test_registry.py (deflated 92%)
# updating: zope/interface/tests/__init__.py (deflated 62%)
# updating: zope/interface/tests/odd.py (deflated 63%)
# updating: zope/interface/tests/test_ro.py (deflated 76%)
# updating: zope/interface/tests/test_exceptions.py (deflated 79%)
# updating: zope/interface/verify.py (deflated 64%)
# updating: zope/interface/document.py (deflated 65%)
# updating: zope/interface/_compat.py (deflated 63%)
# updating: zope/interface/_zope_interface_coptimizations.cpython-36m-x86_64-linux-gnu.so (deflated 66%)
# updating: zope/interface/adapter.py (deflated 78%)
# updating: zope/interface/interfaces.py (deflated 80%)
# updating: zope/interface/exceptions.py (deflated 67%)
# updating: zope/interface/__init__.py (deflated 66%)
# updating: zope/interface/advice.py (deflated 61%)
# updating: zope.interface-5.1.0.dist-info/ (stored 0%)
# updating: zope.interface-5.1.0.dist-info/namespace_packages.txt (stored 0%)
# updating: zope.interface-5.1.0.dist-info/INSTALLER (stored 0%)
# updating: zope.interface-5.1.0.dist-info/RECORD (deflated 65%)
# updating: zope.interface-5.1.0.dist-info/LICENSE.txt (deflated 50%)
# updating: zope.interface-5.1.0.dist-info/top_level.txt (stored 0%)
# updating: zope.interface-5.1.0.dist-info/METADATA (deflated 66%)
# updating: zope.interface-5.1.0.dist-info/WHEEL (deflated 3%)
# updating: zope.interface-5.1.0-py3.6-nspkg.pth (deflated 48%)
# updating: boto3-1.14.31.dist-info/ (stored 0%)
# updating: boto3-1.14.31.dist-info/INSTALLER (stored 0%)
# updating: boto3-1.14.31.dist-info/RECORD (deflated 59%)
# updating: boto3-1.14.31.dist-info/metadata.json (deflated 54%)
# updating: boto3-1.14.31.dist-info/DESCRIPTION.rst (deflated 60%)
# updating: boto3-1.14.31.dist-info/top_level.txt (stored 0%)
# updating: boto3-1.14.31.dist-info/METADATA (deflated 62%)
# updating: boto3-1.14.31.dist-info/WHEEL (deflated 14%)
# updating: botocore-1.17.31.dist-info/ (stored 0%)
# updating: botocore-1.17.31.dist-info/INSTALLER (stored 0%)
# updating: botocore-1.17.31.dist-info/RECORD (deflated 66%)
# updating: botocore-1.17.31.dist-info/metadata.json (deflated 57%)
# updating: botocore-1.17.31.dist-info/DESCRIPTION.rst (deflated 56%)
# updating: botocore-1.17.31.dist-info/top_level.txt (stored 0%)
# updating: botocore-1.17.31.dist-info/METADATA (deflated 59%)
# updating: botocore-1.17.31.dist-info/WHEEL (deflated 14%)
# /home/ec2-user/SageMaker

# %%
# !cp lambda_function.py ./lambda_pkg/lambda_function.py
# %cd lambda_pkg
# !zip -r ../myArizeDeploymentPackage.zip *
# %cd ..
# Out:
# /home/ec2-user/SageMaker/lambda_pkg
# updating: arize/ (stored 0%)
# updating: arize/bounded_executor.py (deflated 60%)
# updating: arize/public_pb2.py (deflated 88%)
# updating: arize/__pycache__/ (stored 0%)
# updating: arize/__pycache__/__init__.cpython-36.pyc (deflated 12%)
# updating: arize/__pycache__/protocol_pb2.cpython-36.pyc (deflated 66%)
# updating: arize/__pycache__/public_pb2.cpython-36.pyc (deflated 64%)
# updating: arize/__pycache__/bounded_executor.cpython-36.pyc (deflated 43%)
# updating: arize/__pycache__/validation_helper.cpython-36.pyc (deflated 57%)
# updating: arize/__pycache__/input_transformer.cpython-36.pyc (deflated 50%)
# updating: arize/__pycache__/api.cpython-36.pyc (deflated 55%)
# updating: arize/input_transformer.py (deflated 71%)
# updating: arize/api.py (deflated 78%)
# updating: arize/__init__.py (stored 0%)
# updating: arize/validation_helper.py (deflated 82%)
# updating: arize/protocol_pb2.py (deflated 91%)
# updating: arize-0.0.20.dist-info/ (stored 0%)
# updating: arize-0.0.20.dist-info/INSTALLER (stored 0%)
# updating: arize-0.0.20.dist-info/RECORD (deflated 49%)
# updating: arize-0.0.20.dist-info/LICENSE.md (deflated 49%)
# updating: arize-0.0.20.dist-info/top_level.txt (stored 0%)
# updating: arize-0.0.20.dist-info/METADATA (deflated 58%)
# updating: arize-0.0.20.dist-info/WHEEL (deflated 14%)
# updating: bin/ (stored 0%)
# updating: bin/f2py (deflated 27%)
# updating: bin/chardetect (deflated 28%)
# updating: bin/f2py3 (deflated 27%)
# updating: bin/f2py3.6 (deflated 27%)
# updating: bin/easy_install (deflated 26%)
# updating: bin/easy_install-3.6 (deflated 26%)
# updating: certifi/ (stored 0%)
# updating: certifi/__pycache__/ (stored 0%)
# updating: certifi/__pycache__/__init__.cpython-36.pyc (deflated 11%)
# updating: certifi/__pycache__/core.cpython-36.pyc (deflated 39%)
# updating: certifi/__pycache__/__main__.cpython-36.pyc (deflated 24%)
# updating: certifi/__main__.py (deflated 39%)
# updating: certifi/core.py (deflated 57%)
# updating: certifi/__init__.py (stored 0%)
# updating: certifi/cacert.pem (deflated 46%)
# updating: certifi-2020.6.20.dist-info/ (stored 0%)
# updating: certifi-2020.6.20.dist-info/INSTALLER (stored 0%)
# updating: certifi-2020.6.20.dist-info/RECORD (deflated 44%)
# updating: certifi-2020.6.20.dist-info/top_level.txt (stored 0%)
# updating: certifi-2020.6.20.dist-info/METADATA (deflated 58%)
# updating: certifi-2020.6.20.dist-info/WHEEL (deflated 14%)
# updating: certifi-2020.6.20.dist-info/LICENSE (deflated 43%)
# updating: chardet/ (stored 0%)
# updating: chardet/langcyrillicmodel.py (deflated 83%)
# updating: chardet/chardistribution.py (deflated 75%)
# updating: chardet/langhungarianmodel.py (deflated 78%)
# updating: chardet/mbcssm.py (deflated 87%)
# updating: chardet/gb2312freq.py (deflated 51%)
# updating: chardet/jpcntx.py (deflated 75%)
# updating: chardet/charsetgroupprober.py (deflated 70%)
# updating: chardet/__pycache__/ (stored 0%)
# updating: chardet/__pycache__/__init__.cpython-36.pyc (deflated 33%)
# updating: chardet/__pycache__/euckrprober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/langthaimodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/escsm.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/version.cpython-36.pyc (deflated 21%)
# updating: chardet/__pycache__/compat.cpython-36.pyc (deflated 18%)
# updating: chardet/__pycache__/mbcssm.cpython-36.pyc (deflated 91%)
# updating: chardet/__pycache__/big5freq.cpython-36.pyc (deflated 53%)
# updating: chardet/__pycache__/langturkishmodel.cpython-36.pyc (deflated 88%)
# updating: chardet/__pycache__/euctwprober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/eucjpprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/mbcsgroupprober.cpython-36.pyc (deflated 41%)
# updating: chardet/__pycache__/sjisprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/utf8prober.cpython-36.pyc (deflated 43%)
# updating: chardet/__pycache__/sbcharsetprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/jpcntx.cpython-36.pyc (deflated 86%)
# updating: chardet/__pycache__/charsetgroupprober.cpython-36.pyc (deflated 46%)
# updating: chardet/__pycache__/mbcharsetprober.cpython-36.pyc (deflated 46%)
# updating: chardet/__pycache__/codingstatemachine.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/escprober.cpython-36.pyc (deflated 45%)
# updating: chardet/__pycache__/jisfreq.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/langhebrewmodel.cpython-36.pyc (deflated 90%)
# updating: chardet/__pycache__/langhungarianmodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/enums.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/euctwfreq.cpython-36.pyc (deflated 53%)
# updating: chardet/__pycache__/gb2312prober.cpython-36.pyc (deflated 43%)
# updating: chardet/__pycache__/charsetprober.cpython-36.pyc (deflated 50%)
# updating: chardet/__pycache__/sbcsgroupprober.cpython-36.pyc (deflated 44%)
# updating: chardet/__pycache__/euckrfreq.cpython-36.pyc (deflated 54%)
# updating: chardet/__pycache__/langbulgarianmodel.cpython-36.pyc (deflated 89%)
# updating: chardet/__pycache__/cp949prober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/chardistribution.cpython-36.pyc (deflated 66%)
# updating: chardet/__pycache__/universaldetector.cpython-36.pyc (deflated 47%)
# updating: chardet/__pycache__/langgreekmodel.cpython-36.pyc (deflated 91%)
# updating: chardet/__pycache__/big5prober.cpython-36.pyc (deflated 42%)
# updating: chardet/__pycache__/hebrewprober.cpython-36.pyc (deflated 48%)
# updating: chardet/__pycache__/gb2312freq.cpython-36.pyc (deflated 51%)
# updating: chardet/__pycache__/langcyrillicmodel.cpython-36.pyc (deflated 90%)
# updating: chardet/__pycache__/latin1prober.cpython-36.pyc (deflated 58%)
# updating: chardet/escsm.py (deflated 85%)
# updating: chardet/euckrprober.py (deflated 53%)
# updating: chardet/euctwfreq.py (deflated 53%)
# updating: chardet/mbcsgroupprober.py (deflated 56%)
# updating: chardet/version.py (deflated 24%)
# updating: chardet/enums.py (deflated 58%)
# updating: chardet/sbcharsetprober.py (deflated 66%)
# updating: chardet/big5freq.py (deflated 53%)
# updating: chardet/sjisprober.py (deflated 65%)
# updating: chardet/universaldetector.py (deflated 72%)
# updating: chardet/langhebrewmodel.py (deflated 78%)
# updating: chardet/sbcsgroupprober.py (deflated 67%)
# updating: chardet/escprober.py (deflated 66%)
# updating: chardet/langgreekmodel.py (deflated 81%)
# updating: chardet/eucjpprober.py (deflated 65%)
# updating: chardet/euckrfreq.py (deflated 54%)
# updating: chardet/cli/ (stored 0%)
# updating: chardet/cli/__pycache__/ (stored 0%)
# updating: chardet/cli/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: chardet/cli/__pycache__/chardetect.cpython-36.pyc (deflated 49%)
# updating: chardet/cli/chardetect.py (deflated 57%)
# updating: chardet/cli/__init__.py (stored 0%)
# updating: chardet/jisfreq.py (deflated 52%)
# updating: chardet/latin1prober.py (deflated 69%)
# updating: chardet/compat.py (deflated 48%)
# updating: chardet/hebrewprober.py (deflated 66%)
# updating: chardet/codingstatemachine.py (deflated 60%)
# updating: chardet/gb2312prober.py (deflated 53%)
# updating: chardet/langturkishmodel.py (deflated 75%)
# updating: chardet/big5prober.py (deflated 53%)
# updating: chardet/mbcharsetprober.py (deflated 64%)
# updating: chardet/__init__.py (deflated 53%)
# updating: chardet/cp949prober.py (deflated 53%)
# updating: chardet/euctwprober.py (deflated 53%)
# updating: chardet/langbulgarianmodel.py (deflated 78%)
# updating: chardet/utf8prober.py (deflated 60%)
# updating: chardet/langthaimodel.py (deflated 75%)
# updating: chardet/charsetprober.py (deflated 61%)
# updating: chardet-3.0.4.dist-info/ (stored 0%)
# updating: chardet-3.0.4.dist-info/INSTALLER (stored 0%)
# updating: chardet-3.0.4.dist-info/RECORD (deflated 59%)
# updating: chardet-3.0.4.dist-info/metadata.json (deflated 57%)
# updating: chardet-3.0.4.dist-info/DESCRIPTION.rst (deflated 53%)
# updating: chardet-3.0.4.dist-info/entry_points.txt (deflated 20%)
# updating: chardet-3.0.4.dist-info/top_level.txt (stored 0%)
# updating: chardet-3.0.4.dist-info/METADATA (deflated 58%)
# updating: chardet-3.0.4.dist-info/WHEEL (deflated 14%)
# updating: dateutil/ (stored 0%)
# updating: dateutil/rrule.py (deflated 77%)
# updating: dateutil/utils.py (deflated 58%)
# updating: dateutil/easter.py (deflated 53%)
# updating: dateutil/__pycache__/ (stored 0%)
# updating: dateutil/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: dateutil/__pycache__/rrule.cpython-36.pyc (deflated 57%)
# updating: dateutil/__pycache__/_version.cpython-36.pyc (deflated 16%)
# updating: dateutil/__pycache__/easter.cpython-36.pyc (deflated 41%)
# updating: dateutil/__pycache__/relativedelta.cpython-36.pyc (deflated 59%)
# updating: dateutil/__pycache__/utils.cpython-36.pyc (deflated 49%)
# updating: dateutil/__pycache__/_common.cpython-36.pyc (deflated 46%)
# updating: dateutil/__pycache__/tzwin.cpython-36.pyc (deflated 13%)
# updating: dateutil/parser/ (stored 0%)
# updating: dateutil/parser/isoparser.py (deflated 71%)
# updating: dateutil/parser/__pycache__/ (stored 0%)
# updating: dateutil/parser/__pycache__/__init__.cpython-36.pyc (deflated 46%)
# updating: dateutil/parser/__pycache__/isoparser.cpython-36.pyc (deflated 55%)
# updating: dateutil/parser/__pycache__/_parser.cpython-36.pyc (deflated 59%)
# updating: dateutil/parser/__init__.py (deflated 66%)
# updating: dateutil/parser/_parser.py (deflated 76%)
# updating: dateutil/tzwin.py (deflated 8%)
# updating: dateutil/_common.py (deflated 61%)
# updating: dateutil/_version.py (deflated 13%)
# updating: dateutil/relativedelta.py (deflated 77%)
# updating: dateutil/zoneinfo/ (stored 0%)
# updating: dateutil/zoneinfo/__pycache__/ (stored 0%)
# updating: dateutil/zoneinfo/__pycache__/__init__.cpython-36.pyc (deflated 54%)
# updating: dateutil/zoneinfo/__pycache__/rebuild.cpython-36.pyc (deflated 34%)
# updating: dateutil/zoneinfo/rebuild.py (deflated 56%)
# updating: dateutil/zoneinfo/dateutil-zoneinfo.tar.gz (deflated 3%)
# updating: dateutil/zoneinfo/__init__.py (deflated 65%)
# updating: dateutil/tz/ (stored 0%)
# updating: dateutil/tz/__pycache__/ (stored 0%)
# updating: dateutil/tz/__pycache__/__init__.cpython-36.pyc (deflated 30%)
# updating: dateutil/tz/__pycache__/_factories.cpython-36.pyc (deflated 55%)
# updating: dateutil/tz/__pycache__/win.cpython-36.pyc (deflated 53%)
# updating: dateutil/tz/__pycache__/_common.cpython-36.pyc (deflated 62%)
# updating: dateutil/tz/__pycache__/tz.cpython-36.pyc (deflated 60%)
# updating: dateutil/tz/_factories.py (deflated 76%)
# updating: dateutil/tz/win.py (deflated 69%)
# updating: dateutil/tz/_common.py (deflated 74%)
# updating: dateutil/tz/tz.py (deflated 75%)
# updating: dateutil/tz/__init__.py (deflated 46%)
# updating: dateutil/__init__.py (deflated 32%)
# updating: easy_install.py (deflated 17%)
# updating: google/ (stored 0%)
# updating: google/longrunning/ (stored 0%)
# updating: google/longrunning/operations_proto.py (deflated 28%)
# updating: google/longrunning/__pycache__/ (stored 0%)
# updating: google/longrunning/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/longrunning/__pycache__/operations_proto_pb2.cpython-36.pyc (deflated 66%)
# updating: google/longrunning/__pycache__/operations_proto.cpython-36.pyc (deflated 20%)
# updating: google/longrunning/__pycache__/operations_grpc_pb2.cpython-36.pyc (deflated 50%)
# updating: google/longrunning/__pycache__/operations_pb2.cpython-36.pyc (deflated 34%)
# updating: google/longrunning/__pycache__/operations_grpc.cpython-36.pyc (deflated 20%)
# updating: google/longrunning/operations_grpc_pb2.py (deflated 67%)
# updating: google/longrunning/operations_pb2.py (deflated 50%)
# updating: google/longrunning/operations_proto_pb2.py (deflated 86%)
# updating: google/longrunning/operations_grpc.py (deflated 28%)
# updating: google/longrunning/__init__.py (stored 0%)
# updating: google/rpc/ (stored 0%)
# updating: google/rpc/__pycache__/ (stored 0%)
# updating: google/rpc/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: google/rpc/__pycache__/error_details_pb2.cpython-36.pyc (deflated 67%)
# updating: google/rpc/__pycache__/status_pb2.cpython-36.pyc (deflated 47%)
# updating: google/rpc/__pycache__/code_pb2.cpython-36.pyc (deflated 49%)
# updating: google/rpc/status_pb2.py (deflated 68%)
# updating: google/rpc/error_details_pb2.py (deflated 89%)
# updating: google/rpc/__init__.py (stored 0%)
# updating: google/rpc/code_pb2.py (deflated 73%)
# updating: google/api/ (stored 0%)
# updating: google/api/httpbody_pb2.py (deflated 68%)
# updating: google/api/system_parameter_pb2.py (deflated 81%)
# updating: google/api/context_pb2.py (deflated 77%)
# updating: google/api/auth_pb2.py (deflated 85%)
# updating: google/api/distribution_pb2.py (deflated 88%)
# updating: google/api/label_pb2.py (deflated 72%)
# updating: google/api/http_pb2.py (deflated 84%)
# updating: google/api/control_pb2.py (deflated 61%)
# updating: google/api/__pycache__/ (stored 0%)
# updating: google/api/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: google/api/__pycache__/log_pb2.cpython-36.pyc (deflated 50%)
# updating: google/api/__pycache__/endpoint_pb2.cpython-36.pyc (deflated 49%)
# updating: google/api/__pycache__/system_parameter_pb2.cpython-36.pyc (deflated 57%)
# updating: google/api/__pycache__/field_behavior_pb2.cpython-36.pyc (deflated 49%)
# updating: google/api/__pycache__/monitoring_pb2.cpython-36.pyc (deflated 54%)
# updating: google/api/__pycache__/client_pb2.cpython-36.pyc (deflated 48%)
# updating: google/api/__pycache__/quota_pb2.cpython-36.pyc (deflated 62%)
# updating: google/api/__pycache__/label_pb2.cpython-36.pyc (deflated 50%)
# updating: google/api/__pycache__/service_pb2.cpython-36.pyc (deflated 64%)
# updating: google/api/__pycache__/source_info_pb2.cpython-36.pyc (deflated 47%)
# updating: google/api/__pycache__/distribution_pb2.cpython-36.pyc (deflated 66%)
# updating: google/api/__pycache__/auth_pb2.cpython-36.pyc (deflated 61%)
# updating: google/api/__pycache__/metric_pb2.cpython-36.pyc (deflated 62%)
# updating: google/api/__pycache__/documentation_pb2.cpython-36.pyc (deflated 59%)
# updating: google/api/__pycache__/launch_stage_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/control_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/consumer_pb2.cpython-36.pyc (deflated 52%)
# updating: google/api/__pycache__/usage_pb2.cpython-36.pyc (deflated 52%)
# updating: google/api/__pycache__/config_change_pb2.cpython-36.pyc (deflated 53%)
# updating: google/api/__pycache__/annotations_pb2.cpython-36.pyc (deflated 46%)
# updating: google/api/__pycache__/http_pb2.cpython-36.pyc (deflated 60%)
# updating: google/api/__pycache__/httpbody_pb2.cpython-36.pyc (deflated 47%)
# updating: google/api/__pycache__/backend_pb2.cpython-36.pyc (deflated 55%)
# updating: google/api/__pycache__/monitored_resource_pb2.cpython-36.pyc (deflated 63%)
# updating: google/api/__pycache__/resource_pb2.cpython-36.pyc (deflated 56%)
# updating: google/api/__pycache__/billing_pb2.cpython-36.pyc (deflated 51%)
# updating: google/api/__pycache__/logging_pb2.cpython-36.pyc (deflated 53%)
# updating: google/api/__pycache__/context_pb2.cpython-36.pyc (deflated 54%)
# updating: google/api/usage_pb2.py (deflated 76%)
# updating: google/api/launch_stage_pb2.py (deflated 66%)
# updating: google/api/quota_pb2.py (deflated 86%)
# updating: google/api/documentation_pb2.py (deflated 83%)
# updating: google/api/backend_pb2.py (deflated 79%)
# updating: google/api/source_info_pb2.py (deflated 63%)
# updating: google/api/resource_pb2.py (deflated 79%)
# updating: google/api/consumer_pb2.py (deflated 76%)
# updating: google/api/field_behavior_pb2.py (deflated 68%)
# updating: google/api/annotations_pb2.py (deflated 60%)
# updating: google/api/config_change_pb2.py (deflated 77%)
# updating: google/api/metric_pb2.py (deflated 85%)
# updating: google/api/__init__.py (stored 0%)
# updating: google/api/monitoring_pb2.py (deflated 76%)
# updating: google/api/client_pb2.py (deflated 69%)
# updating: google/api/log_pb2.py (deflated 72%)
# updating: google/api/monitored_resource_pb2.py (deflated 86%)
# updating: google/api/billing_pb2.py (deflated 73%)
# updating: google/api/logging_pb2.py (deflated 76%)
# updating: google/api/service_pb2.py (deflated 85%)
# updating: google/api/endpoint_pb2.py (deflated 73%)
# updating: google/logging/ (stored 0%)
# updating: google/logging/type/ (stored 0%)
# updating: google/logging/type/__pycache__/ (stored 0%)
# updating: google/logging/type/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/logging/type/__pycache__/log_severity_pb2.cpython-36.pyc (deflated 46%)
# updating: google/logging/type/__pycache__/http_request_pb2.cpython-36.pyc (deflated 59%)
# updating: google/logging/type/log_severity_pb2.py (deflated 68%)
# updating: google/logging/type/http_request_pb2.py (deflated 82%)
# updating: google/logging/type/__init__.py (stored 0%)
# updating: google/type/ (stored 0%)
# updating: google/type/color_pb2.py (deflated 71%)
# updating: google/type/postal_address_pb2.py (deflated 81%)
# updating: google/type/dayofweek_pb2.py (deflated 69%)
# updating: google/type/__pycache__/ (stored 0%)
# updating: google/type/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: google/type/__pycache__/fraction_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/quaternion_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/latlng_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/timeofday_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/money_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/date_pb2.cpython-36.pyc (deflated 47%)
# updating: google/type/__pycache__/calendar_period_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/expr_pb2.cpython-36.pyc (deflated 50%)
# updating: google/type/__pycache__/dayofweek_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/__pycache__/postal_address_pb2.cpython-36.pyc (deflated 59%)
# updating: google/type/__pycache__/color_pb2.cpython-36.pyc (deflated 48%)
# updating: google/type/expr_pb2.py (deflated 72%)
# updating: google/type/calendar_period_pb2.py (deflated 69%)
# updating: google/type/date_pb2.py (deflated 69%)
# updating: google/type/fraction_pb2.py (deflated 66%)
# updating: google/type/latlng_pb2.py (deflated 66%)
# updating: google/type/__init__.py (stored 0%)
# updating: google/type/timeofday_pb2.py (deflated 72%)
# updating: google/type/quaternion_pb2.py (deflated 73%)
# updating: google/type/money_pb2.py (deflated 68%)
# updating: google/protobuf/ (stored 0%)
# updating: google/protobuf/unittest_no_generic_services_pb2.py (deflated 72%)
# updating: google/protobuf/struct_pb2.py (deflated 83%)
# updating: google/protobuf/test_messages_proto3_pb2.py (deflated 93%)
# updating: google/protobuf/source_context_pb2.py (deflated 63%)
# updating: google/protobuf/unittest_proto3_arena_pb2.py (deflated 91%)
# updating: google/protobuf/unittest_arena_pb2.py (deflated 76%)
# updating: google/protobuf/message.py (deflated 65%)
# updating: google/protobuf/descriptor_database.py (deflated 64%)
# updating: google/protobuf/type_pb2.py (deflated 87%)
# updating: google/protobuf/symbol_database.py (deflated 65%)
# updating: google/protobuf/compiler/ (stored 0%)
# updating: google/protobuf/compiler/__pycache__/ (stored 0%)
# updating: google/protobuf/compiler/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/protobuf/compiler/__pycache__/plugin_pb2.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/compiler/plugin_pb2.py (deflated 85%)
# updating: google/protobuf/compiler/__init__.py (stored 0%)
# updating: google/protobuf/unittest_no_arena_import_pb2.py (deflated 66%)
# updating: google/protobuf/service_reflection.py (deflated 72%)
# updating: google/protobuf/__pycache__/ (stored 0%)
# updating: google/protobuf/__pycache__/unittest_proto3_arena_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: google/protobuf/__pycache__/unittest_no_generic_services_pb2.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/__pycache__/text_format.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/__pycache__/descriptor_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/descriptor.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/__pycache__/service.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/__pycache__/text_encoding.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/__pycache__/unittest_import_public_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/unittest_import_pb2.cpython-36.pyc (deflated 52%)
# updating: google/protobuf/__pycache__/message_factory.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/proto_builder.cpython-36.pyc (deflated 44%)
# updating: google/protobuf/__pycache__/test_messages_proto3_pb2.cpython-36.pyc (deflated 80%)
# updating: google/protobuf/__pycache__/unittest_pb2.cpython-36.pyc (deflated 79%)
# updating: google/protobuf/__pycache__/map_proto2_unittest_pb2.cpython-36.pyc (deflated 75%)
# updating: google/protobuf/__pycache__/source_context_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/unittest_custom_options_pb2.cpython-36.pyc (deflated 70%)
# updating: google/protobuf/__pycache__/any_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/any_test_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/struct_pb2.cpython-36.pyc (deflated 59%)
# updating: google/protobuf/__pycache__/duration_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/json_format.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/__pycache__/unittest_mset_pb2.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/__pycache__/symbol_database.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/__pycache__/test_messages_proto2_pb2.cpython-36.pyc (deflated 80%)
# updating: google/protobuf/__pycache__/type_pb2.cpython-36.pyc (deflated 65%)
# updating: google/protobuf/__pycache__/message.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/__pycache__/map_unittest_pb2.cpython-36.pyc (deflated 81%)
# updating: google/protobuf/__pycache__/unittest_no_arena_import_pb2.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/service_reflection.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/__pycache__/timestamp_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/__pycache__/reflection.cpython-36.pyc (deflated 47%)
# updating: google/protobuf/__pycache__/api_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/__pycache__/wrappers_pb2.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/__pycache__/unittest_no_arena_pb2.cpython-36.pyc (deflated 74%)
# updating: google/protobuf/__pycache__/unittest_mset_wire_format_pb2.cpython-36.pyc (deflated 51%)
# updating: google/protobuf/__pycache__/descriptor_database.cpython-36.pyc (deflated 56%)
# updating: google/protobuf/__pycache__/empty_pb2.cpython-36.pyc (deflated 46%)
# updating: google/protobuf/__pycache__/field_mask_pb2.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/__pycache__/descriptor_pool.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/__pycache__/unittest_arena_pb2.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/unittest_import_public_pb2.py (deflated 65%)
# updating: google/protobuf/json_format.py (deflated 77%)
# updating: google/protobuf/wrappers_pb2.py (deflated 87%)
# updating: google/protobuf/descriptor_pb2.py (deflated 91%)
# updating: google/protobuf/internal/ (stored 0%)
# updating: google/protobuf/internal/extension_dict.py (deflated 65%)
# updating: google/protobuf/internal/test_bad_identifiers_pb2.py (deflated 77%)
# updating: google/protobuf/internal/_parameterized.py (deflated 66%)
# updating: google/protobuf/internal/json_format_test.py (deflated 82%)
# updating: google/protobuf/internal/_api_implementation.cpython-36m-x86_64-linux-gnu.so (deflated 64%)
# updating: google/protobuf/internal/proto_builder_test.py (deflated 61%)
# updating: google/protobuf/internal/message_test.py (deflated 82%)
# updating: google/protobuf/internal/testing_refleaks.py (deflated 57%)
# updating: google/protobuf/internal/encoder.py (deflated 79%)
# updating: google/protobuf/internal/message_factory_test.py (deflated 72%)
# updating: google/protobuf/internal/message_listener.py (deflated 52%)
# updating: google/protobuf/internal/factory_test1_pb2.py (deflated 84%)
# updating: google/protobuf/internal/__pycache__/ (stored 0%)
# updating: google/protobuf/internal/__pycache__/test_util.cpython-36.pyc (deflated 69%)
# updating: google/protobuf/internal/__pycache__/message_factory_test.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/internal/__pycache__/__init__.cpython-36.pyc (deflated 17%)
# updating: google/protobuf/internal/__pycache__/encoder.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/decoder.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test1_pb2.cpython-36.pyc (deflated 73%)
# updating: google/protobuf/internal/__pycache__/symbol_database_test.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/wire_format_test.cpython-36.pyc (deflated 59%)
# updating: google/protobuf/internal/__pycache__/json_format_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/test_bad_identifiers_pb2.cpython-36.pyc (deflated 54%)
# updating: google/protobuf/internal/__pycache__/descriptor_database_test.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/message_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/api_implementation.cpython-36.pyc (deflated 45%)
# updating: google/protobuf/internal/__pycache__/missing_enum_values_pb2.cpython-36.pyc (deflated 65%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test2_pb2.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/descriptor_test.cpython-36.pyc (deflated 66%)
# updating: google/protobuf/internal/__pycache__/enum_type_wrapper.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/python_message.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/internal/__pycache__/any_test_pb2.cpython-36.pyc (deflated 56%)
# updating: google/protobuf/internal/__pycache__/_parameterized.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/reflection_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/text_encoding_test.cpython-36.pyc (deflated 42%)
# updating: google/protobuf/internal/__pycache__/unknown_fields_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/keywords_test.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/proto_builder_test.cpython-36.pyc (deflated 50%)
# updating: google/protobuf/internal/__pycache__/packed_field_test_pb2.cpython-36.pyc (deflated 73%)
# updating: google/protobuf/internal/__pycache__/more_extensions_dynamic_pb2.cpython-36.pyc (deflated 58%)
# updating: google/protobuf/internal/__pycache__/containers.cpython-36.pyc (deflated 68%)
# updating: google/protobuf/internal/__pycache__/well_known_types.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/service_reflection_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/descriptor_pool_test.cpython-36.pyc (deflated 67%)
# updating: google/protobuf/internal/__pycache__/file_options_test_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/internal/__pycache__/extension_dict.cpython-36.pyc (deflated 55%)
# updating: google/protobuf/internal/__pycache__/well_known_types_test.cpython-36.pyc (deflated 63%)
# updating: google/protobuf/internal/__pycache__/text_format_test.cpython-36.pyc (deflated 72%)
# updating: google/protobuf/internal/__pycache__/type_checkers.cpython-36.pyc (deflated 60%)
# updating: google/protobuf/internal/__pycache__/generator_test.cpython-36.pyc (deflated 61%)
# updating: google/protobuf/internal/__pycache__/message_listener.cpython-36.pyc (deflated 51%)
# updating: google/protobuf/internal/__pycache__/factory_test1_pb2.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/internal/__pycache__/more_extensions_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/internal/__pycache__/factory_test2_pb2.cpython-36.pyc (deflated 70%)
# updating: google/protobuf/internal/__pycache__/message_set_extensions_pb2.cpython-36.pyc (deflated 62%)
# updating: google/protobuf/internal/__pycache__/more_messages_pb2.cpython-36.pyc (deflated 82%)
# updating: google/protobuf/internal/__pycache__/no_package_pb2.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/internal/__pycache__/wire_format.cpython-36.pyc (deflated 57%)
# updating: google/protobuf/internal/__pycache__/testing_refleaks.cpython-36.pyc (deflated 48%)
# updating: google/protobuf/internal/more_extensions_dynamic_pb2.py (deflated 77%)
# updating: google/protobuf/internal/no_package_pb2.py (deflated 68%)
# updating: google/protobuf/internal/api_implementation.py (deflated 61%)
# updating: google/protobuf/internal/descriptor_pool_test.py (deflated 84%)
# updating: google/protobuf/internal/wire_format_test.py (deflated 75%)
# updating: google/protobuf/internal/well_known_types_test.py (deflated 81%)
# updating: google/protobuf/internal/symbol_database_test.py (deflated 70%)
# updating: google/protobuf/internal/test_util.py (deflated 83%)
# updating: google/protobuf/internal/text_format_test.py (deflated 85%)
# updating: google/protobuf/internal/well_known_types.py (deflated 73%)
# updating: google/protobuf/internal/descriptor_database_test.py (deflated 69%)
# updating: google/protobuf/internal/service_reflection_test.py (deflated 68%)
# updating: google/protobuf/internal/import_test_package/ (stored 0%)
# updating: google/protobuf/internal/import_test_package/__pycache__/ (stored 0%)
# updating: google/protobuf/internal/import_test_package/__pycache__/__init__.cpython-36.pyc (deflated 26%)
# updating: google/protobuf/internal/import_test_package/__pycache__/inner_pb2.cpython-36.pyc (deflated 49%)
# updating: google/protobuf/internal/import_test_package/__pycache__/outer_pb2.cpython-36.pyc (deflated 53%)
# updating: google/protobuf/internal/import_test_package/inner_pb2.py (deflated 65%)
# updating: google/protobuf/internal/import_test_package/__init__.py (deflated 47%)
# updating: google/protobuf/internal/import_test_package/outer_pb2.py (deflated 68%)
# updating: google/protobuf/internal/reflection_test.py (deflated 83%)
# updating: google/protobuf/internal/factory_test2_pb2.py (deflated 88%)
# updating: google/protobuf/internal/missing_enum_values_pb2.py (deflated 85%)
# updating: google/protobuf/internal/more_extensions_pb2.py (deflated 83%)
# updating: google/protobuf/internal/wire_format.py (deflated 65%)
# updating: google/protobuf/internal/python_message.py (deflated 75%)
# updating: google/protobuf/internal/message_set_extensions_pb2.py (deflated 84%)
# updating: google/protobuf/internal/decoder.py (deflated 78%)
# updating: google/protobuf/internal/descriptor_pool_test1_pb2.py (deflated 90%)
# updating: google/protobuf/internal/descriptor_pool_test2_pb2.py (deflated 86%)
# updating: google/protobuf/internal/keywords_test.py (deflated 64%)
# updating: google/protobuf/internal/text_encoding_test.py (deflated 55%)
# updating: google/protobuf/internal/any_test_pb2.py (deflated 81%)
# updating: google/protobuf/internal/__init__.py (deflated 48%)
# updating: google/protobuf/internal/enum_type_wrapper.py (deflated 61%)
# updating: google/protobuf/internal/generator_test.py (deflated 75%)
# updating: google/protobuf/internal/descriptor_test.py (deflated 82%)
# updating: google/protobuf/internal/unknown_fields_test.py (deflated 79%)
# updating: google/protobuf/internal/containers.py (deflated 76%)
# updating: google/protobuf/internal/packed_field_test_pb2.py (deflated 90%)
# updating: google/protobuf/internal/type_checkers.py (deflated 74%)
# updating: google/protobuf/internal/file_options_test_pb2.py (deflated 68%)
# updating: google/protobuf/internal/more_messages_pb2.py (deflated 94%)
# updating: google/protobuf/reflection.py (deflated 54%)
# updating: google/protobuf/duration_pb2.py (deflated 66%)
# updating: google/protobuf/map_proto2_unittest_pb2.py (deflated 92%)
# updating: google/protobuf/text_encoding.py (deflated 56%)
# updating: google/protobuf/message_factory.py (deflated 61%)
# updating: google/protobuf/text_format.py (deflated 78%)
# updating: google/protobuf/test_messages_proto2_pb2.py (deflated 93%)
# updating: google/protobuf/service.py (deflated 62%)
# updating: google/protobuf/unittest_import_pb2.py (deflated 74%)
# updating: google/protobuf/descriptor_pool.py (deflated 78%)
# updating: google/protobuf/descriptor.py (deflated 76%)
# updating: google/protobuf/map_unittest_pb2.py (deflated 93%)
# updating: google/protobuf/util/ (stored 0%)
# updating: google/protobuf/util/__pycache__/ (stored 0%)
# updating: google/protobuf/util/__pycache__/json_format_pb2.cpython-36.pyc (deflated 70%)
# updating: google/protobuf/util/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: google/protobuf/util/__pycache__/json_format_proto3_pb2.cpython-36.pyc (deflated 76%)
# updating: google/protobuf/util/json_format_proto3_pb2.py (deflated 92%)
# updating: google/protobuf/util/__init__.py (stored 0%)
# updating: google/protobuf/util/json_format_pb2.py (deflated 91%)
# updating: google/protobuf/api_pb2.py (deflated 85%)
# updating: google/protobuf/pyext/ (stored 0%)
# updating: google/protobuf/pyext/python_pb2.py (deflated 84%)
# updating: google/protobuf/pyext/_message.cpython-36m-x86_64-linux-gnu.so (deflated 66%)
# updating: google/protobuf/pyext/__pycache__/ (stored 0%)
# updating: google/protobuf/pyext/__pycache__/__init__.cpython-36.pyc (deflated 17%)
# updating: google/protobuf/pyext/__pycache__/cpp_message.cpython-36.pyc (deflated 44%)
# updating: google/protobuf/pyext/__pycache__/python_pb2.cpython-36.pyc (deflated 64%)
# updating: google/protobuf/pyext/cpp_message.py (deflated 50%)
# updating: google/protobuf/pyext/__init__.py (deflated 28%)
# updating: google/protobuf/unittest_mset_pb2.py (deflated 85%)
# updating: google/protobuf/empty_pb2.py (deflated 60%)
# updating: google/protobuf/any_test_pb2.py (deflated 72%)
# updating: google/protobuf/timestamp_pb2.py (deflated 66%)
# updating: google/protobuf/unittest_no_arena_pb2.py (deflated 90%)
# updating: google/protobuf/__init__.py (deflated 47%)
# updating: google/protobuf/unittest_pb2.py (deflated 92%)
# updating: google/protobuf/field_mask_pb2.py (deflated 62%)
# updating: google/protobuf/unittest_mset_wire_format_pb2.py (deflated 72%)
# updating: google/protobuf/unittest_custom_options_pb2.py (deflated 88%)
# updating: google/protobuf/proto_builder.py (deflated 60%)
# updating: google/protobuf/any_pb2.py (deflated 65%)
# updating: googleapis_common_protos-1.51.0.dist-info/ (stored 0%)
# updating: googleapis_common_protos-1.51.0.dist-info/namespace_packages.txt (deflated 9%)
# updating: googleapis_common_protos-1.51.0.dist-info/INSTALLER (stored 0%)
# updating: googleapis_common_protos-1.51.0.dist-info/RECORD (deflated 64%)
# updating: googleapis_common_protos-1.51.0.dist-info/top_level.txt (stored 0%)
# updating: googleapis_common_protos-1.51.0.dist-info/METADATA (deflated 59%)
# updating: googleapis_common_protos-1.51.0.dist-info/WHEEL (stored 0%)
# updating: googleapis_common_protos-1.51.0.dist-info/LICENSE (deflated 65%)
# updating: googleapis_common_protos-1.51.0-py3.6-nspkg.pth (deflated 80%)
# updating: idna/ (stored 0%)
# updating: idna/__pycache__/ (stored 0%)
# updating: idna/__pycache__/idnadata.cpython-36.pyc (deflated 67%)
# updating: idna/__pycache__/__init__.cpython-36.pyc (deflated 14%)
# updating: idna/__pycache__/compat.cpython-36.pyc (deflated 39%)
# updating: idna/__pycache__/uts46data.cpython-36.pyc (deflated 73%)
# updating: idna/__pycache__/package_data.cpython-36.pyc (deflated 13%)
# updating: idna/__pycache__/codec.cpython-36.pyc (deflated 56%)
# updating: idna/__pycache__/core.cpython-36.pyc (deflated 51%)
# updating: idna/__pycache__/intranges.cpython-36.pyc (deflated 41%)
# updating: idna/uts46data.py (deflated 81%)
# updating: idna/package_data.py (stored 0%)
# updating: idna/intranges.py (deflated 58%)
# updating: idna/codec.py (deflated 76%)
# updating: idna/core.py (deflated 76%)
# updating: idna/compat.py (deflated 38%)
# updating: idna/idnadata.py (deflated 79%)
# updating: idna/__init__.py (deflated 12%)
# updating: idna-2.10.dist-info/ (stored 0%)
# updating: idna-2.10.dist-info/INSTALLER (stored 0%)
# updating: idna-2.10.dist-info/RECORD (deflated 48%)
# updating: idna-2.10.dist-info/LICENSE.rst (deflated 48%)
# updating: idna-2.10.dist-info/top_level.txt (stored 0%)
# updating: idna-2.10.dist-info/METADATA (deflated 63%)
# updating: idna-2.10.dist-info/WHEEL (deflated 14%)
# updating: lambda_function.py (deflated 64%)
# updating: numpy/ (stored 0%)
# updating: numpy/doc/ (stored 0%)
# updating: numpy/doc/structured_arrays.py (deflated 68%)
# updating: numpy/doc/glossary.py (deflated 66%)
# updating: numpy/doc/byteswapping.py (deflated 64%)
# updating: numpy/doc/__pycache__/ (stored 0%)
# updating: numpy/doc/__pycache__/__init__.cpython-36.pyc (deflated 28%)
# updating: numpy/doc/__pycache__/ufuncs.cpython-36.pyc (deflated 57%)
# updating: numpy/doc/__pycache__/indexing.cpython-36.pyc (deflated 64%)
# updating: numpy/doc/__pycache__/constants.cpython-36.pyc (deflated 72%)
# updating: numpy/doc/__pycache__/structured_arrays.cpython-36.pyc (deflated 68%)
# updating: numpy/doc/__pycache__/byteswapping.cpython-36.pyc (deflated 62%)
# updating: numpy/doc/__pycache__/misc.cpython-36.pyc (deflated 56%)
# updating: numpy/doc/__pycache__/creation.cpython-36.pyc (deflated 55%)
# updating: numpy/doc/__pycache__/dispatch.cpython-36.pyc (deflated 72%)
# updating: numpy/doc/__pycache__/broadcasting.cpython-36.pyc (deflated 60%)
# updating: numpy/doc/__pycache__/glossary.cpython-36.pyc (deflated 65%)
# updating: numpy/doc/__pycache__/subclassing.cpython-36.pyc (deflated 68%)
# updating: numpy/doc/__pycache__/basics.cpython-36.pyc (deflated 64%)
# updating: numpy/doc/__pycache__/internals.cpython-36.pyc (deflated 59%)
# updating: numpy/doc/broadcasting.py (deflated 62%)
# updating: numpy/doc/ufuncs.py (deflated 58%)
# updating: numpy/doc/creation.py (deflated 56%)
# updating: numpy/doc/subclassing.py (deflated 69%)
# updating: numpy/doc/dispatch.py (deflated 73%)
# updating: numpy/doc/indexing.py (deflated 65%)
# updating: numpy/doc/misc.py (deflated 57%)
# updating: numpy/doc/internals.py (deflated 60%)
# updating: numpy/doc/basics.py (deflated 65%)
# updating: numpy/doc/__init__.py (deflated 41%)
# updating: numpy/doc/constants.py (deflated 79%)
# updating: numpy/f2py/ (stored 0%)
# updating: numpy/f2py/capi_maps.py (deflated 78%)
# updating: numpy/f2py/setup.py (deflated 55%)
# updating: numpy/f2py/src/ (stored 0%)
# updating: numpy/f2py/src/fortranobject.h (deflated 68%)
# updating: numpy/f2py/src/fortranobject.c (deflated 77%)
# updating: numpy/f2py/__pycache__/ (stored 0%)
# updating: numpy/f2py/__pycache__/__init__.cpython-36.pyc (deflated 42%)
# updating: numpy/f2py/__pycache__/capi_maps.cpython-36.pyc (deflated 50%)
# updating: numpy/f2py/__pycache__/f90mod_rules.cpython-36.pyc (deflated 49%)
# updating: numpy/f2py/__pycache__/cb_rules.cpython-36.pyc (deflated 62%)
# updating: numpy/f2py/__pycache__/common_rules.cpython-36.pyc (deflated 44%)
# updating: numpy/f2py/__pycache__/cfuncs.cpython-36.pyc (deflated 74%)
# updating: numpy/f2py/__pycache__/func2subr.cpython-36.pyc (deflated 50%)
# updating: numpy/f2py/__pycache__/f2py_testing.cpython-36.pyc (deflated 35%)
# updating: numpy/f2py/__pycache__/diagnose.cpython-36.pyc (deflated 56%)
# updating: numpy/f2py/__pycache__/f2py2e.cpython-36.pyc (deflated 54%)
# updating: numpy/f2py/__pycache__/setup.cpython-36.pyc (deflated 40%)
# updating: numpy/f2py/__pycache__/crackfortran.cpython-36.pyc (deflated 55%)
# updating: numpy/f2py/__pycache__/rules.cpython-36.pyc (deflated 62%)
# updating: numpy/f2py/__pycache__/use_rules.cpython-36.pyc (deflated 39%)
# updating: numpy/f2py/__pycache__/auxfuncs.cpython-36.pyc (deflated 63%)
# updating: numpy/f2py/__pycache__/__main__.cpython-36.pyc (deflated 17%)
# updating: numpy/f2py/__pycache__/__version__.cpython-36.pyc (deflated 23%)
# updating: numpy/f2py/cb_rules.py (deflated 78%)
# updating: numpy/f2py/common_rules.py (deflated 64%)
# updating: numpy/f2py/auxfuncs.py (deflated 78%)
# updating: numpy/f2py/__main__.py (deflated 19%)
# updating: numpy/f2py/rules.py (deflated 80%)
# updating: numpy/f2py/cfuncs.py (deflated 80%)
# updating: numpy/f2py/f90mod_rules.py (deflated 70%)
# updating: numpy/f2py/tests/ (stored 0%)
# updating: numpy/f2py/tests/test_mixed.py (deflated 56%)
# updating: numpy/f2py/tests/test_regression.py (deflated 45%)
# updating: numpy/f2py/tests/test_semicolon_split.py (deflated 68%)
# updating: numpy/f2py/tests/test_array_from_pyobj.py (deflated 82%)
# updating: numpy/f2py/tests/test_size.py (deflated 70%)
# updating: numpy/f2py/tests/src/ (stored 0%)
# updating: numpy/f2py/tests/src/kind/ (stored 0%)
# updating: numpy/f2py/tests/src/kind/foo.f90 (deflated 59%)
# updating: numpy/f2py/tests/src/parameter/ (stored 0%)
# updating: numpy/f2py/tests/src/parameter/constant_non_compound.f90 (deflated 50%)
# updating: numpy/f2py/tests/src/parameter/constant_real.f90 (deflated 60%)
# updating: numpy/f2py/tests/src/parameter/constant_both.f90 (deflated 81%)
# updating: numpy/f2py/tests/src/parameter/constant_integer.f90 (deflated 61%)
# updating: numpy/f2py/tests/src/parameter/constant_compound.f90 (deflated 47%)
# updating: numpy/f2py/tests/src/array_from_pyobj/ (stored 0%)
# updating: numpy/f2py/tests/src/array_from_pyobj/wrapmodule.c (deflated 69%)
# updating: numpy/f2py/tests/src/common/ (stored 0%)
# updating: numpy/f2py/tests/src/common/block.f (deflated 45%)
# updating: numpy/f2py/tests/src/size/ (stored 0%)
# updating: numpy/f2py/tests/src/size/foo.f90 (deflated 66%)
# updating: numpy/f2py/tests/src/mixed/ (stored 0%)
# updating: numpy/f2py/tests/src/mixed/foo_free.f90 (deflated 32%)
# updating: numpy/f2py/tests/src/mixed/foo_fixed.f90 (deflated 45%)
# updating: numpy/f2py/tests/src/mixed/foo.f (deflated 25%)
# updating: numpy/f2py/tests/src/string/ (stored 0%)
# updating: numpy/f2py/tests/src/string/char.f90 (deflated 62%)
# updating: numpy/f2py/tests/src/assumed_shape/ (stored 0%)
# updating: numpy/f2py/tests/src/assumed_shape/foo_use.f90 (deflated 39%)
# updating: numpy/f2py/tests/src/assumed_shape/foo_free.f90 (deflated 63%)
# updating: numpy/f2py/tests/src/assumed_shape/foo_mod.f90 (deflated 62%)
# updating: numpy/f2py/tests/src/assumed_shape/.f2py_f2cmap (deflated 7%)
# updating: numpy/f2py/tests/src/assumed_shape/precision.f90 (deflated 38%)
# updating: numpy/f2py/tests/src/regression/ (stored 0%)
# updating: numpy/f2py/tests/src/regression/inout.f90 (deflated 42%)
# updating: numpy/f2py/tests/test_parameter.py (deflated 84%)
# updating: numpy/f2py/tests/__pycache__/ (stored 0%)
# updating: numpy/f2py/tests/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: numpy/f2py/tests/__pycache__/test_return_character.cpython-36.pyc (deflated 67%)
# updating: numpy/f2py/tests/__pycache__/test_compile_function.cpython-36.pyc (deflated 42%)
# updating: numpy/f2py/tests/__pycache__/test_return_integer.cpython-36.pyc (deflated 69%)
# updating: numpy/f2py/tests/__pycache__/test_block_docstring.cpython-36.pyc (deflated 33%)
# updating: numpy/f2py/tests/__pycache__/test_assumed_shape.cpython-36.pyc (deflated 44%)
# updating: numpy/f2py/tests/__pycache__/test_kind.cpython-36.pyc (deflated 40%)
# updating: numpy/f2py/tests/__pycache__/test_size.cpython-36.pyc (deflated 50%)
# updating: numpy/f2py/tests/__pycache__/test_common.cpython-36.pyc (deflated 37%)
# updating: numpy/f2py/tests/__pycache__/test_semicolon_split.cpython-36.pyc (deflated 54%)
# updating: numpy/f2py/tests/__pycache__/test_callback.cpython-36.pyc (deflated 61%)
# updating: numpy/f2py/tests/__pycache__/test_string.cpython-36.pyc (deflated 35%)
# updating: numpy/f2py/tests/__pycache__/test_return_real.cpython-36.pyc (deflated 66%)
# updating: numpy/f2py/tests/__pycache__/test_mixed.cpython-36.pyc (deflated 41%)
# updating: numpy/f2py/tests/__pycache__/util.cpython-36.pyc (deflated 49%)
# updating: numpy/f2py/tests/__pycache__/test_array_from_pyobj.cpython-36.pyc (deflated 62%)
# updating: numpy/f2py/tests/__pycache__/test_regression.cpython-36.pyc (deflated 37%)
# updating: numpy/f2py/tests/__pycache__/test_return_complex.cpython-36.pyc (deflated 67%)
# updating: numpy/f2py/tests/__pycache__/test_quoted_character.cpython-36.pyc (deflated 41%)
# updating: numpy/f2py/tests/__pycache__/test_return_logical.cpython-36.pyc (deflated 71%)
# updating: numpy/f2py/tests/__pycache__/test_parameter.cpython-36.pyc (deflated 70%)
# updating: numpy/f2py/tests/test_callback.py (deflated 72%)
# updating: numpy/f2py/tests/test_block_docstring.py (deflated 38%)
# updating: numpy/f2py/tests/test_quoted_character.py (deflated 48%)
# updating: numpy/f2py/tests/test_kind.py (deflated 62%)
# updating: numpy/f2py/tests/test_return_complex.py (deflated 79%)
# updating: numpy/f2py/tests/test_return_logical.py (deflated 82%)
# updating: numpy/f2py/tests/test_return_character.py (deflated 79%)
# updating: numpy/f2py/tests/test_string.py (deflated 47%)
# updating: numpy/f2py/tests/test_compile_function.py (deflated 59%)
# updating: numpy/f2py/tests/test_assumed_shape.py (deflated 65%)
# updating: numpy/f2py/tests/test_common.py (deflated 53%)
# updating: numpy/f2py/tests/test_return_integer.py (deflated 81%)
# updating: numpy/f2py/tests/util.py (deflated 73%)
# updating: numpy/f2py/tests/__init__.py (stored 0%)
# updating: numpy/f2py/tests/test_return_real.py (deflated 78%)
# updating: numpy/f2py/__version__.py (deflated 40%)
# updating: numpy/f2py/f2py_testing.py (deflated 63%)
# updating: numpy/f2py/use_rules.py (deflated 60%)
# updating: numpy/f2py/diagnose.py (deflated 81%)
# updating: numpy/f2py/__init__.py (deflated 61%)
# updating: numpy/f2py/func2subr.py (deflated 78%)
# updating: numpy/f2py/crackfortran.py (deflated 79%)
# updating: numpy/f2py/f2py2e.py (deflated 71%)
# updating: numpy/setup.py (deflated 64%)
# updating: numpy/_globals.py (deflated 56%)
# updating: numpy/distutils/ (stored 0%)
# updating: numpy/distutils/cpuinfo.py (deflated 80%)
# updating: numpy/distutils/_shell_utils.py (deflated 61%)
# updating: numpy/distutils/lib2def.py (deflated 63%)
# updating: numpy/distutils/extension.py (deflated 70%)
# updating: numpy/distutils/mingw32ccompiler.py (deflated 69%)
# updating: numpy/distutils/setup.py (deflated 53%)
# updating: numpy/distutils/conv_template.py (deflated 65%)
# updating: numpy/distutils/command/ (stored 0%)
# updating: numpy/distutils/command/install_data.py (deflated 60%)
# updating: numpy/distutils/command/build.py (deflated 64%)
# updating: numpy/distutils/command/install_headers.py (deflated 58%)
# updating: numpy/distutils/command/build_ext.py (deflated 79%)
# updating: numpy/distutils/command/__pycache__/ (stored 0%)
# updating: numpy/distutils/command/__pycache__/__init__.cpython-36.pyc (deflated 35%)
# updating: numpy/distutils/command/__pycache__/config.cpython-36.pyc (deflated 56%)
# updating: numpy/distutils/command/__pycache__/install_headers.cpython-36.pyc (deflated 36%)
# updating: numpy/distutils/command/__pycache__/build_clib.cpython-36.pyc (deflated 49%)
# updating: numpy/distutils/command/__pycache__/build_py.cpython-36.pyc (deflated 45%)
# updating: numpy/distutils/command/__pycache__/develop.cpython-36.pyc (deflated 38%)
# updating: numpy/distutils/command/__pycache__/install_clib.cpython-36.pyc (deflated 45%)
# updating: numpy/distutils/command/__pycache__/config_compiler.cpython-36.pyc (deflated 57%)
# updating: numpy/distutils/command/__pycache__/autodist.cpython-36.pyc (deflated 63%)
# updating: numpy/distutils/command/__pycache__/install_data.cpython-36.pyc (deflated 42%)
# updating: numpy/distutils/command/__pycache__/build.cpython-36.pyc (deflated 44%)
# updating: numpy/distutils/command/__pycache__/build_ext.cpython-36.pyc (deflated 49%)
# updating: numpy/distutils/command/__pycache__/sdist.cpython-36.pyc (deflated 37%)
# updating: numpy/distutils/command/__pycache__/install.cpython-36.pyc (deflated 41%)
# updating: numpy/distutils/command/__pycache__/build_src.cpython-36.pyc (deflated 52%)
# updating: numpy/distutils/command/__pycache__/build_scripts.cpython-36.pyc (deflated 45%)
# updating: numpy/distutils/command/__pycache__/bdist_rpm.cpython-36.pyc (deflated 37%)
# ...
# updating: s3transfer-0.3.3.dist-info/top_level.txt (stored 0%)
# updating: s3transfer-0.3.3.dist-info/METADATA (deflated 57%)
# updating: s3transfer-0.3.3.dist-info/WHEEL (deflated 14%)
# updating: fsspec/ (stored 0%)
# updating: fsspec/compression.py (deflated 65%)
# updating: fsspec/caching.py (deflated 73%)
# updating: fsspec/utils.py (deflated 64%)
# updating: fsspec/__pycache__/ (stored 0%)
# updating: fsspec/__pycache__/caching.cpython-36.pyc (deflated 55%)
# updating: fsspec/__pycache__/__init__.cpython-36.pyc (deflated 34%)
# updating: fsspec/__pycache__/_version.cpython-36.pyc (deflated 27%)
# updating: fsspec/__pycache__/compression.cpython-36.pyc (deflated 47%)
# updating: fsspec/__pycache__/mapping.cpython-36.pyc (deflated 51%)
# updating: fsspec/__pycache__/dircache.cpython-36.pyc (deflated 52%)
# updating: fsspec/__pycache__/fuse.cpython-36.pyc (deflated 52%)
# updating: fsspec/__pycache__/spec.cpython-36.pyc (deflated 60%)
# updating: fsspec/__pycache__/registry.cpython-36.pyc (deflated 55%)
# updating: fsspec/__pycache__/transaction.cpython-36.pyc (deflated 56%)
# updating: fsspec/__pycache__/conftest.cpython-36.pyc (deflated 36%)
# updating: fsspec/__pycache__/utils.cpython-36.pyc (deflated 51%)
# updating: fsspec/__pycache__/core.cpython-36.pyc (deflated 57%)
# updating: fsspec/__pycache__/gui.cpython-36.pyc (deflated 54%)
# updating: fsspec/registry.py (deflated 70%)
# updating: fsspec/transaction.py (deflated 69%)
# updating: fsspec/spec.py (deflated 72%)
# updating: fsspec/mapping.py (deflated 64%)
# updating: fsspec/core.py (deflated 72%)
# updating: fsspec/_version.py (deflated 30%)
# updating: fsspec/conftest.py (deflated 57%)
# updating: fsspec/dircache.py (deflated 67%)
# updating: fsspec/implementations/ (stored 0%)
# updating: fsspec/implementations/dask.py (deflated 73%)
# updating: fsspec/implementations/hdfs.py (deflated 70%)
# updating: fsspec/implementations/git.py (deflated 69%)
# updating: fsspec/implementations/dvc.py (deflated 60%)
# updating: fsspec/implementations/__pycache__/ (stored 0%)
# updating: fsspec/implementations/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: fsspec/implementations/__pycache__/ftp.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/dvc.cpython-36.pyc (deflated 42%)
# updating: fsspec/implementations/__pycache__/cached.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/zip.cpython-36.pyc (deflated 46%)
# updating: fsspec/implementations/__pycache__/hdfs.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/webhdfs.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/memory.cpython-36.pyc (deflated 50%)
# updating: fsspec/implementations/__pycache__/git.cpython-36.pyc (deflated 44%)
# updating: fsspec/implementations/__pycache__/sftp.cpython-36.pyc (deflated 51%)
# updating: fsspec/implementations/__pycache__/dask.cpython-36.pyc (deflated 54%)
# updating: fsspec/implementations/__pycache__/local.cpython-36.pyc (deflated 54%)
# updating: fsspec/implementations/__pycache__/github.cpython-36.pyc (deflated 53%)
# updating: fsspec/implementations/__pycache__/http.cpython-36.pyc (deflated 49%)
# updating: fsspec/implementations/local.py (deflated 70%)
# updating: fsspec/implementations/ftp.py (deflated 70%)
# updating: fsspec/implementations/zip.py (deflated 66%)
# updating: fsspec/implementations/memory.py (deflated 72%)
# updating: fsspec/implementations/webhdfs.py (deflated 69%)
# updating: fsspec/implementations/cached.py (deflated 75%)
# updating: fsspec/implementations/http.py (deflated 68%)
# updating: fsspec/implementations/github.py (deflated 67%)
# updating: fsspec/implementations/sftp.py (deflated 65%)
# updating: fsspec/implementations/__init__.py (stored 0%)
# updating: fsspec/fuse.py (deflated 67%)
# updating: fsspec/__init__.py (deflated 60%)
# updating: fsspec/gui.py (deflated 69%)
# updating: fsspec-0.7.4.dist-info/ (stored 0%)
# updating: fsspec-0.7.4.dist-info/INSTALLER (stored 0%)
# updating: fsspec-0.7.4.dist-info/RECORD (deflated 59%)
# updating: fsspec-0.7.4.dist-info/top_level.txt (stored 0%)
# updating: fsspec-0.7.4.dist-info/METADATA (deflated 58%)
# updating: fsspec-0.7.4.dist-info/WHEEL (stored 0%)
# updating: fsspec-0.7.4.dist-info/LICENSE (deflated 48%)
# updating: s3fs/ (stored 0%)
# updating: s3fs/errors.py (deflated 75%)
# updating: s3fs/utils.py (deflated 60%)
# updating: s3fs/__pycache__/ (stored 0%)
# updating: s3fs/__pycache__/__init__.cpython-36.pyc (deflated 21%)
# updating: s3fs/__pycache__/_version.cpython-36.pyc (deflated 26%)
# updating: s3fs/__pycache__/mapping.cpython-36.pyc (deflated 22%)
# updating: s3fs/__pycache__/errors.cpython-36.pyc (deflated 53%)
# updating: s3fs/__pycache__/utils.cpython-36.pyc (deflated 49%)
# updating: s3fs/__pycache__/core.cpython-36.pyc (deflated 57%)
# updating: s3fs/mapping.py (deflated 32%)
# updating: s3fs/core.py (deflated 75%)
# updating: s3fs/_version.py (deflated 30%)
# updating: s3fs/__init__.py (deflated 41%)
# updating: s3fs-0.4.2.dist-info/ (stored 0%)
# updating: s3fs-0.4.2.dist-info/INSTALLER (stored 0%)
# updating: s3fs-0.4.2.dist-info/RECORD (deflated 46%)
# updating: s3fs-0.4.2.dist-info/pbr.json (stored 0%)
# updating: s3fs-0.4.2.dist-info/LICENSE.txt (deflated 47%)
# updating: s3fs-0.4.2.dist-info/top_level.txt (stored 0%)
# updating: s3fs-0.4.2.dist-info/METADATA (deflated 56%)
# updating: s3fs-0.4.2.dist-info/WHEEL (stored 0%)
# updating: DateTime/ (stored 0%)
# updating: DateTime/pytz.txt (deflated 64%)
# updating: DateTime/__pycache__/ (stored 0%)
# updating: DateTime/__pycache__/__init__.cpython-36.pyc (deflated 22%)
# updating: DateTime/__pycache__/pytz_support.cpython-36.pyc (deflated 56%)
# updating: DateTime/__pycache__/DateTime.cpython-36.pyc (deflated 65%)
# updating: DateTime/__pycache__/interfaces.cpython-36.pyc (deflated 76%)
# updating: DateTime/DateTime.py (deflated 76%)
# updating: DateTime/tests/ (stored 0%)
# updating: DateTime/tests/__pycache__/ (stored 0%)
# updating: DateTime/tests/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: DateTime/tests/__pycache__/test_datetime.cpython-36.pyc (deflated 62%)
# updating: DateTime/tests/__init__.py (deflated 46%)
# updating: DateTime/tests/test_datetime.py (deflated 76%)
# updating: DateTime/tests/julian_testdata.txt (deflated 78%)
# updating: DateTime/interfaces.py (deflated 78%)
# updating: DateTime/__init__.py (deflated 47%)
# updating: DateTime/pytz_support.py (deflated 73%)
# updating: DateTime/DateTime.txt (deflated 72%)
# updating: DateTime-4.3.dist-info/ (stored 0%)
# updating: DateTime-4.3.dist-info/INSTALLER (stored 0%)
# updating: DateTime-4.3.dist-info/RECORD (deflated 48%)
# updating: DateTime-4.3.dist-info/metadata.json (deflated 55%)
# updating: DateTime-4.3.dist-info/DESCRIPTION.rst (deflated 70%)
# updating: DateTime-4.3.dist-info/top_level.txt (stored 0%)
# updating: DateTime-4.3.dist-info/METADATA (deflated 70%)
# updating: DateTime-4.3.dist-info/WHEEL (deflated 14%)
# updating: zope/ (stored 0%)
# updating: zope/interface/ (stored 0%)
# updating: zope/interface/_zope_interface_coptimizations.c (deflated 82%)
# updating: zope/interface/ro.py (deflated 67%)
# updating: zope/interface/declarations.py (deflated 74%)
# updating: zope/interface/_flatten.py (deflated 49%)
# updating: zope/interface/interface.py (deflated 71%)
# updating: zope/interface/__pycache__/ (stored 0%)
# updating: zope/interface/__pycache__/__init__.cpython-36.pyc (deflated 50%)
# updating: zope/interface/__pycache__/ro.cpython-36.pyc (deflated 57%)
# updating: zope/interface/__pycache__/advice.cpython-36.pyc (deflated 46%)
# updating: zope/interface/__pycache__/_compat.cpython-36.pyc (deflated 51%)
# updating: zope/interface/__pycache__/document.cpython-36.pyc (deflated 45%)
# updating: zope/interface/__pycache__/registry.cpython-36.pyc (deflated 66%)
# updating: zope/interface/__pycache__/verify.cpython-36.pyc (deflated 46%)
# updating: zope/interface/__pycache__/interfaces.cpython-36.pyc (deflated 78%)
# updating: zope/interface/__pycache__/exceptions.cpython-36.pyc (deflated 59%)
# updating: zope/interface/__pycache__/declarations.cpython-36.pyc (deflated 65%)
# updating: zope/interface/__pycache__/adapter.cpython-36.pyc (deflated 62%)
# updating: zope/interface/__pycache__/_flatten.cpython-36.pyc (deflated 27%)
# updating: zope/interface/__pycache__/interface.cpython-36.pyc (deflated 58%)
# updating: zope/interface/registry.py (deflated 81%)
# updating: zope/interface/common/ (stored 0%)
# updating: zope/interface/common/numbers.py (deflated 59%)
# updating: zope/interface/common/io.py (deflated 52%)
# updating: zope/interface/common/sequence.py (deflated 67%)
# updating: zope/interface/common/__pycache__/ (stored 0%)
# updating: zope/interface/common/__pycache__/__init__.cpython-36.pyc (deflated 56%)
# updating: zope/interface/common/__pycache__/numbers.cpython-36.pyc (deflated 57%)
# updating: zope/interface/common/__pycache__/mapping.cpython-36.pyc (deflated 65%)
# updating: zope/interface/common/__pycache__/interfaces.cpython-36.pyc (deflated 74%)
# updating: zope/interface/common/__pycache__/idatetime.cpython-36.pyc (deflated 72%)
# updating: zope/interface/common/__pycache__/sequence.cpython-36.pyc (deflated 67%)
# updating: zope/interface/common/__pycache__/io.cpython-36.pyc (deflated 46%)
# updating: zope/interface/common/__pycache__/collections.cpython-36.pyc (deflated 64%)
# updating: zope/interface/common/__pycache__/builtins.cpython-36.pyc (deflated 57%)
# updating: zope/interface/common/collections.py (deflated 69%)
# updating: zope/interface/common/builtins.py (deflated 62%)
# updating: zope/interface/common/mapping.py (deflated 65%)
# updating: zope/interface/common/idatetime.py (deflated 75%)
# updating: zope/interface/common/tests/ (stored 0%)
# updating: zope/interface/common/tests/test_collections.py (deflated 65%)
# updating: zope/interface/common/tests/test_builtins.py (deflated 56%)
# updating: zope/interface/common/tests/test_idatetime.py (deflated 61%)
# updating: zope/interface/common/tests/__pycache__/ (stored 0%)
# updating: zope/interface/common/tests/__pycache__/__init__.cpython-36.pyc (deflated 47%)
# updating: zope/interface/common/tests/__pycache__/test_builtins.cpython-36.pyc (deflated 40%)
# updating: zope/interface/common/tests/__pycache__/basemapping.cpython-36.pyc (deflated 66%)
# updating: zope/interface/common/tests/__pycache__/test_idatetime.cpython-36.pyc (deflated 45%)
# updating: zope/interface/common/tests/__pycache__/test_numbers.cpython-36.pyc (deflated 46%)
# updating: zope/interface/common/tests/__pycache__/test_io.cpython-36.pyc (deflated 53%)
# updating: zope/interface/common/tests/__pycache__/test_collections.cpython-36.pyc (deflated 60%)
# updating: zope/interface/common/tests/__pycache__/test_import_interfaces.cpython-36.pyc (deflated 41%)
# updating: zope/interface/common/tests/basemapping.py (deflated 76%)
# updating: zope/interface/common/tests/test_import_interfaces.py (deflated 46%)
# updating: zope/interface/common/tests/test_io.py (deflated 59%)
# updating: zope/interface/common/tests/test_numbers.py (deflated 56%)
# updating: zope/interface/common/tests/__init__.py (deflated 66%)
# updating: zope/interface/common/interfaces.py (deflated 77%)
# updating: zope/interface/common/__init__.py (deflated 65%)
# updating: zope/interface/tests/ (stored 0%)
# updating: zope/interface/tests/test_document.py (deflated 89%)
# updating: zope/interface/tests/test_verify.py (deflated 87%)
# updating: zope/interface/tests/test_sorting.py (deflated 62%)
# updating: zope/interface/tests/test_interfaces.py (deflated 86%)
# updating: zope/interface/tests/dummy.py (deflated 47%)
# updating: zope/interface/tests/__pycache__/ (stored 0%)
# updating: zope/interface/tests/__pycache__/__init__.cpython-36.pyc (deflated 50%)
# updating: zope/interface/tests/__pycache__/test_advice.cpython-36.pyc (deflated 72%)
# updating: zope/interface/tests/__pycache__/test_adapter.cpython-36.pyc (deflated 79%)
# updating: zope/interface/tests/__pycache__/test_ro.cpython-36.pyc (deflated 71%)
# updating: zope/interface/tests/__pycache__/advisory_testing.cpython-36.pyc (deflated 42%)
# updating: zope/interface/tests/__pycache__/odd.cpython-36.pyc (deflated 56%)
# updating: zope/interface/tests/__pycache__/test_element.cpython-36.pyc (deflated 39%)
# updating: zope/interface/tests/__pycache__/test_sorting.cpython-36.pyc (deflated 61%)
# updating: zope/interface/tests/__pycache__/test_document.cpython-36.pyc (deflated 85%)
# updating: zope/interface/tests/__pycache__/idummy.cpython-36.pyc (deflated 39%)
# updating: zope/interface/tests/__pycache__/test_interface.cpython-36.pyc (deflated 78%)
# updating: zope/interface/tests/__pycache__/test_odd_declarations.cpython-36.pyc (deflated 73%)
# updating: zope/interface/tests/__pycache__/test_exceptions.cpython-36.pyc (deflated 72%)
# updating: zope/interface/tests/__pycache__/m1.cpython-36.pyc (deflated 40%)
# updating: zope/interface/tests/__pycache__/dummy.cpython-36.pyc (deflated 29%)
# updating: zope/interface/tests/__pycache__/test_verify.cpython-36.pyc (deflated 84%)
# updating: zope/interface/tests/__pycache__/test_declarations.cpython-36.pyc (deflated 79%)
# updating: zope/interface/tests/__pycache__/test_interfaces.cpython-36.pyc (deflated 74%)
# updating: zope/interface/tests/__pycache__/test_registry.cpython-36.pyc (deflated 82%)
# updating: zope/interface/tests/test_element.py (deflated 51%)
# updating: zope/interface/tests/test_declarations.py (deflated 87%)
# updating: zope/interface/tests/test_adapter.py (deflated 90%)
# updating: zope/interface/tests/idummy.py (deflated 48%)
# updating: zope/interface/tests/advisory_testing.py (deflated 53%)
# updating: zope/interface/tests/test_advice.py (deflated 78%)
# updating: zope/interface/tests/test_interface.py (deflated 86%)
# updating: zope/interface/tests/m1.py (deflated 47%)
# updating: zope/interface/tests/test_odd_declarations.py (deflated 77%)
# updating: zope/interface/tests/test_registry.py (deflated 92%)
# updating: zope/interface/tests/__init__.py (deflated 62%)
# updating: zope/interface/tests/odd.py (deflated 63%)
# updating: zope/interface/tests/test_ro.py (deflated 76%)
# updating: zope/interface/tests/test_exceptions.py (deflated 79%)
# updating: zope/interface/verify.py (deflated 64%)
# updating: zope/interface/document.py (deflated 65%)
# updating: zope/interface/_compat.py (deflated 63%)
# updating: zope/interface/_zope_interface_coptimizations.cpython-36m-x86_64-linux-gnu.so (deflated 66%)
# updating: zope/interface/adapter.py (deflated 78%)
# updating: zope/interface/interfaces.py (deflated 80%)
# updating: zope/interface/exceptions.py (deflated 67%)
# updating: zope/interface/__init__.py (deflated 66%)
# updating: zope/interface/advice.py (deflated 61%)
# updating: zope.interface-5.1.0.dist-info/ (stored 0%)
# updating: zope.interface-5.1.0.dist-info/namespace_packages.txt (stored 0%)
# updating: zope.interface-5.1.0.dist-info/INSTALLER (stored 0%)
# updating: zope.interface-5.1.0.dist-info/RECORD (deflated 65%)
# updating: zope.interface-5.1.0.dist-info/LICENSE.txt (deflated 50%)
# updating: zope.interface-5.1.0.dist-info/top_level.txt (stored 0%)
# updating: zope.interface-5.1.0.dist-info/METADATA (deflated 66%)
# updating: zope.interface-5.1.0.dist-info/WHEEL (deflated 3%)
# updating: zope.interface-5.1.0-py3.6-nspkg.pth (deflated 48%)
# updating: boto3-1.14.31.dist-info/ (stored 0%)
# updating: boto3-1.14.31.dist-info/INSTALLER (stored 0%)
# updating: boto3-1.14.31.dist-info/RECORD (deflated 59%)
# updating: boto3-1.14.31.dist-info/metadata.json (deflated 54%)
# updating: boto3-1.14.31.dist-info/DESCRIPTION.rst (deflated 60%)
# updating: boto3-1.14.31.dist-info/top_level.txt (stored 0%)
# updating: boto3-1.14.31.dist-info/METADATA (deflated 62%)
# updating: boto3-1.14.31.dist-info/WHEEL (deflated 14%)
# updating: botocore-1.17.31.dist-info/ (stored 0%)
# updating: botocore-1.17.31.dist-info/INSTALLER (stored 0%)
# updating: botocore-1.17.31.dist-info/RECORD (deflated 66%)
# updating: botocore-1.17.31.dist-info/metadata.json (deflated 57%)
# updating: botocore-1.17.31.dist-info/DESCRIPTION.rst (deflated 56%)
# updating: botocore-1.17.31.dist-info/top_level.txt (stored 0%)
# updating: botocore-1.17.31.dist-info/METADATA (deflated 59%)
# updating: botocore-1.17.31.dist-info/WHEEL (deflated 14%)
# /home/ec2-user/SageMaker

# %%
batch_input_loc =sess.upload_data(path='myArizeDeploymentPackage.zip', key_prefix='{}/deploy'.format(prefix))

# %% [markdown]
# #### Copy the file path to the Lambda Server - S3 Location

# %%
print(batch_input_loc)
# Out:
# s3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/deploy/myArizeDeploymentPackage.zip

# %% [markdown]
# ### Configuring A Lambda
# The Lambda Function needs to have the following:
#
# Lambda needs to be same Python Version as where you are building the Lambda Gzip. Given we are building it on this server we are going to print the version below. In this example it is Python 3.6

# %% [markdown]
# Create a Lambda Function
#
# Python needs to be the same version running on this server where we created the GZIP
#
# This example is Python 3.6 (set Python to version output below)
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p2.png?" width="500" height="600">

# %%
#Print out Python Version of local server
import sys
sys.version
# Out:
# '3.6.10 |Anaconda, Inc.| (default, Mar 25 2020, 23:51:54) \n[GCC 7.3.0]'

# %% [markdown]
# ##### Create a role to access S3
# Lambda needs to read from S3 files. Create a role to read S3 either bucket specific or general S3 Readonly.
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p3.png" width="500" height="600">

# %% [markdown]
# S3 Readonly Example role below
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p4.png" width="500" height="600">

# %% [markdown]
# Function is created
#
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p5.png" width="500" height="600">

# %% [markdown]
# Set file for execution to be Gzip lambda_function file we loaded to S3
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p6.png" width="500" height="600">

# %% [markdown]
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p7.png" width="500" height="600">

# %%
#Insert this into S3 URL Link above
print(batch_input_loc)
# Out:
# s3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/deploy/myArizeDeploymentPackage.zip

# %% [markdown]
# #### Set function to run for longer than 3 seconds -> 10Min
# The actual runtime is typically pretty short but if there is a lot of data it's good to set to 10min.
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p8.png" width="500" height="600">

# %% [markdown]
# ##### Batch Event Test
# We are creating JSON that can be inserted as a test function into the Lambda Test Config section - once the lambda function is uploaded. It represents the data returned by the batch event once the batch process is done.

# %%
test_json = {
  "version": "0",
  "id": "844e2571-85d4-695f-b930-0153b71dcb42",
  "detail-type": "SageMaker Transform Job State Change",
  "source": "aws.sagemaker",
  "account": "123456789012",
  "time": "2018-10-06T12:26:13Z",
  "region": "us-east-1",
  "resources": [
    "arn:aws:sagemaker:us-east-1:123456789012:transform-job/myjob"
  ],
  "detail": {
    "TransformJobName": "4b52bd8f-e034-4345-818d-884bdd7c9724",
    "TransformJobArn": "arn:aws:sagemaker:us-east-1:123456789012:transform-job/myjob",
    "TransformJobStatus": "Completed",
    "FailureReason": "failed why 1",
    "ModelName": "i am a beautiful model",
    "MaxConcurrentTransforms": 5,
    "MaxPayloadInMB": 10,
    "BatchStrategy": "Strategizing...",
    "Environment": {
      "bucket": bucket,
      "input_location": input_location,
      "model_name": model_name,
      "model_version":model_version,
      "batch_id": batch_id,
      "prefix": prefix,
      "ArizeMonitor": "1",
      "features_file": features_file,
      "batch_file": batch_file_noID
    },
    "TransformInput": {
      "DataSource": {
        "S3DataSource": {
          "S3DataType": "s3DataType",
          "S3Uri": "s3Uri"
        }
      },
      "ContentType": "content type",
      "CompressionType": "compression type",
      "SplitType": "split type"
    },
    "TransformOutput": {
      "S3OutputPath": "s3://sagemaker-us-east-2-783112096916/xgboost-2020-07-28-05-16-52-914",
      "Accept": "accept",
      "AssembleWith": "assemblyType",
      "KmsKeyId": "kmsKeyId"
    },
    "TransformResources": {
      "InstanceType": "instanceType",
      "InstanceCount": 3
    },
    "CreationTime": "2018-10-06T12:26:13Z",
    "TransformStartTime": "2018-10-06T12:26:13Z",
    "TransformEndTime": "2018-10-06T12:26:13Z",
    "Tags": {}
  }
}

# %% [markdown]
# #### Copy Paste below into Lambda Test Config

# %% [markdown]
# The below json should be copied into the test config when creating the Lambda function.

# %%
import json
print(json.dumps(test_json))
# Out:
# {"version": "0", "id": "844e2571-85d4-695f-b930-0153b71dcb42", "detail-type": "SageMaker Transform Job State Change", "source": "aws.sagemaker", "account": "123456789012", "time": "2018-10-06T12:26:13Z", "region": "us-east-1", "resources": ["arn:aws:sagemaker:us-east-1:123456789012:transform-job/myjob"], "detail": {"TransformJobName": "4b52bd8f-e034-4345-818d-884bdd7c9724", "TransformJobArn": "arn:aws:sagemaker:us-east-1:123456789012:transform-job/myjob", "TransformJobStatus": "Completed", "FailureReason": "failed why 1", "ModelName": "i am a beautiful model", "MaxConcurrentTransforms": 5, "MaxPayloadInMB": 10, "BatchStrategy": "Strategizing...", "Environment": {"bucket": "sagemaker-us-east-2-783112096916", "input_location": "s3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/batch/batch_data_noID.csv", "model_name": "sage_batch_test", "model_version": "test_v_1.0", "batch_id": "batch_10", "prefix": "sagemaker/breast-cancer-prediction-xgboost", "ArizeMonitor": "1", "features_file": "s3://sagemaker-us-east-2-783112096916/sagemaker/breast-cancer-prediction-xgboost/features/features.csv", "batch_file": "batch_data_noID.csv"}, "TransformInput": {"DataSource": {"S3DataSource": {"S3DataType": "s3DataType", "S3Uri": "s3Uri"}}, "ContentType": "content type", "CompressionType": "compression type", "SplitType": "split type"}, "TransformOutput": {"S3OutputPath": "s3://sagemaker-us-east-2-783112096916/xgboost-2020-07-28-05-16-52-914", "Accept": "accept", "AssembleWith": "assemblyType", "KmsKeyId": "kmsKeyId"}, "TransformResources": {"InstanceType": "instanceType", "InstanceCount": 3}, "CreationTime": "2018-10-06T12:26:13Z", "TransformStartTime": "2018-10-06T12:26:13Z", "TransformEndTime": "2018-10-06T12:26:13Z", "Tags": {}}}

# %% [markdown]
# Copy the above test JSON into the Lambda Test config. Click the JSON formating button to clean it up. This will allow you to test your Lambda without having the Transformer fire the event.
#
# <img src="https://storage.googleapis.com/arize-assets/tutorials/sagemaker/batch/p10.png" width="500" height="600">

# %% [markdown]
# ### Run Transformer
# This runs the transformer process setup above, this transformer when done throws an event that the Lambda function watches for. The event calls the lambda function with the configuration similar to the above

# %% [markdown]
# ####  Join the input and the prediction results
# Now, let's associate the prediction results with their corresponding input records. We can also use the __input_filter__ to exclude the ID column easily and there's no need to have a separate file in S3.
#
# * Set __input_filter__ to "$[1:]": indicates that we are excluding column 0 (the 'ID') before processing the inferences and keeping everything from column 1 to the last column (all the features or predictors)
#
#
# * Set __join_source__ to "Input": indicates our desire to join the input data with the inference results
#
# * Leave __output_filter__ to default ('$'), indicating that the joined input and inference results be will saved as output.

# %%
# %%time


sm_transformer = sm_estimator.transformer(1, 'ml.m4.xlarge')
sm_transformer.accept = 'text/csv'
sm_transformer.assemble_with = 'Line'
sm_transformer.env = env_var
# start a transform job
sm_transformer.transform(input_location, split_type='Line',content_type='text/csv', input_filter='$[1:]', join_source='Input')
sm_transformer.wait()
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ......................Arguments: serve
# [2020-07-29 22:27:34 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-07-29 22:27:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-07-29 22:27:34 +0000] [1] [INFO] Using worker: gevent
# [2020-07-29 22:27:34 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-07-29 22:27:34 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-07-29:22:27:34:INFO] Model loaded successfully for worker : 37
# [2020-07-29 22:27:34 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-07-29:22:27:34:INFO] Model loaded successfully for worker : 38
# [2020-07-29 22:27:34 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-07-29:22:27:34:INFO] Model loaded successfully for worker : 39
# [2020-07-29:22:27:35:INFO] Model loaded successfully for worker : 40
# [2020-07-29:22:27:42:INFO] Sniff delimiter as ','
# [2020-07-29:22:27:42:INFO] Determined delimiter of CSV input is ','
# [2020-07-29:22:27:42:INFO] Sniff delimiter as ','
# [2020-07-29:22:27:42:INFO] Determined delimiter of CSV input is ','
# 2020-07-29T22:27:41.941:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# CPU times: user 585 ms, sys: 0 ns, total: 585 ms
# Wall time: 4min 12s

# %% [markdown]
# #### Actuals
# The linking of actuals back to the batch job is shown in the example below. We use both the Batch_ID and number of prediction to create a prediction ID.

# %%
actuals_df = data[batch_list]['diagnosis'].reset_index()
actuals_df
# Out:
#     index  diagnosis
# 0       0          1
# 1      12          1
# 2      14          1
# 3      16          1
# 4      17          1
# 5      20          0
# 6      23          1
# 7      25          1
# 8      29          1
# 9      54          1
# 10     68          0
# 11     71          0
# 12    104          0
# 13    118          1
# 14    131          1
# 15    142          0
# 16    149          0
# 17    150          0
# 18    152          0
# 19    158          0
# 20    163          0
# 21    173          0
# 22    201          1
# 23    236          1
# 24    250          1
# 25    254          1
# 26    269          0
# 27    276          0
# 28    297          1
# 29    302          1
# 30    315          0
# 31    326          0
# 32    339          1
# 33    354          0
# 34    358          0
# 35    376          0
# 36    379          1
# 37    385          1
# 38    387          0
# 39    423          0
# 40    449          1
# 41    457          0
# 42    472          0
# 43    485          0
# 44    508          0
# 45    514          1
# 46    529          0
# 47    532          0
# 48    542          0
# 49    550          0
# 50    551          0

# %%
from arize.api import Client
from arize.utils.types import ModelTypes
#SPACE KEY - SUPPLIED BY ARIZE
space_key = 'SPACE KEY'
#API KEY - GENERATED IN ARIZE ACCOUNT OR SUPPLIED
api_key = 'API KEY'

arize_client = Client(space_key=space_key, api_key=api_key)

# %%
actuals_df = data[batch_list]['diagnosis'].reset_index()
ids = pd.DataFrame([str(x) + '_' + batch_id for x in actuals_df.index])
tfuture = arize_client.log_bulk_actuals(model_id=model_name, model_type=ModelTypes.CATEGORICAL, prediction_ids=ids, actual_labels=actuals_df)

# %%
import concurrent.futures as cf
for response in cf.as_completed(tfuture):
  res = response.result()
  print(f'future completed with response code {res.status_code}, {res.text}')
# Out:
# <Response [200]>

# %%
print('Finished Notebook')

# %% [markdown]
# ### Overview
# Arize is an end-to-end ML observability and model monitoring platform. The platform is designed to help ML engineers and data science practitioners surface and fix issues with ML models in production faster with:
# - Automated ML monitoring and model monitoring
# - Workflows to troubleshoot model performance
# - Real-time visualizations for model performance monitoring, data quality monitoring, and drift monitoring
# - Model prediction cohort analysis
# - Pre-deployment model validation
# - Integrated model explainability
#
# ### Website
# Visit Us At: https://arize.com/model-monitoring/
#
# ### Additional Resources
# - [What is ML observability?](https://arize.com/what-is-ml-observability/)
# - [Playbook to model monitoring in production](https://arize.com/the-playbook-to-monitor-your-models-performance-in-production/)
# - [Using statistical distance metrics for ML monitoring and observability](https://arize.com/using-statistical-distance-metrics-for-machine-learning-observability/)
# - [ML infrastructure tools for data preparation](https://arize.com/ml-infrastructure-tools-for-data-preparation/)
# - [ML infrastructure tools for model building](https://arize.com/ml-infrastructure-tools-for-model-building/)
# - [ML infrastructure tools for production](https://arize.com/ml-infrastructure-tools-for-production-part-1/)
# - [ML infrastructure tools for model deployment and model serving](https://arize.com/ml-infrastructure-tools-for-production-part-2-model-deployment-and-serving/)
# - [ML infrastructure tools for ML monitoring and observability](https://arize.com/ml-infrastructure-tools-ml-observability/)
#
# Visit the [Arize Blog](https://arize.com/blog) and [Resource Center](https://arize.com/resource-hub/) for more resources on ML observability and model monitoring.
