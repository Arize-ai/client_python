# %% [markdown]
# # Obtain Spans Data

# %%
from pathlib import Path

DATAFILE = "./spans_data.parquet"
file_path = Path(DATAFILE)

if file_path.exists() and file_path.is_file():
    import pandas as pd

    print(f"{DATAFILE} found!, loading from file")
    spans_df = pd.read_parquet(DATAFILE)
else:
    print(
        f"{DATAFILE} not found, installing phoenix client and downloading data from phoenix cloud"
    )
    # !pip install -q arize-phoenix-client
    # Cloud Instance
    PHOENIX_API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJBcGlLZXk6MSJ9.1wP7wKDG6HGEg254UdEGPXjNy5iCODb8L1YNf60YhQk"
    PHOENIX_BASE_URL = "https://app.phoenix.arize.com/s/phoenix"
    PHOENIX_PROJECT_NAME = "playground"

    from phoenix.client import Client

    # Cloud instance with API key
    client = Client(
        base_url=PHOENIX_BASE_URL,
        api_key=PHOENIX_API_KEY,
    )

    spans_df = client.spans.get_spans_dataframe(
        project_identifier=PHOENIX_PROJECT_NAME,
        limit=2,
    )
    spans_df.to_parquet(DATAFILE)

spans_df
# Out:
# ./spans_data.parquet not found, installing phoenix client and downloading data from phoenix cloud
#                             name span_kind parent_id  \
# context.span_id
# 8d2de1581a113ca   ChatCompletion       LLM      None
# feb2c01e935b49f9  ChatCompletion       LLM      None
#
#                                        start_time  \
# context.span_id
# 8d2de1581a113ca  2025-10-28 22:35:37.199210+00:00
# feb2c01e935b49f9 2025-10-28 22:35:22.029498+00:00
#
#                                          end_time status_code status_message  \
# context.span_id
# 8d2de1581a113ca  2025-10-28 22:35:52.345950+00:00          OK
# feb2c01e935b49f9 2025-10-28 22:35:24.131643+00:00          OK
#
#                  events   context.span_id                  context.trace_id  \
# context.span_id
# 8d2de1581a113ca      []   8d2de1581a113ca  20fbe07c68e9b62569ca7c0d846c7395
# feb2c01e935b49f9     []  feb2c01e935b49f9  b0f57dbd02a3c2aa5a3e1addc23fa2a5
#
#                   ...                     attributes.llm.output_messages  \
# context.span_id   ...
# 8d2de1581a113ca   ...  [{'message.role': 'assistant', 'message.conten...
# feb2c01e935b49f9  ...  [{'message.role': 'assistant', 'message.conten...
#
#                   attributes.llm.token_count.total  \
# context.span_id
# 8d2de1581a113ca                                470
# feb2c01e935b49f9                                25
#
#                                              attributes.input.value  \
# context.span_id
# 8d2de1581a113ca   {"messages": [{"role": "SYSTEM", "content": "Y...
# feb2c01e935b49f9  {"messages": [{"role": "SYSTEM", "content": "Y...
#
#                  attributes.llm.invocation_parameters  \
# context.span_id
# 8d2de1581a113ca    {"temperature": 1.0, "top_p": 1.0}
# feb2c01e935b49f9   {"temperature": 1.0, "top_p": 1.0}
#
#                   attributes.llm.token_count.completion  \
# context.span_id
# 8d2de1581a113ca                                     448
# feb2c01e935b49f9                                      7
#
#                   attributes.llm.model_name  \
# context.span_id
# 8d2de1581a113ca                      gpt-4o
# feb2c01e935b49f9                     gpt-4o
#
#                                       attributes.llm.input_messages  \
# context.span_id
# 8d2de1581a113ca   [{'message.role': 'system', 'message.content':...
# feb2c01e935b49f9  [{'message.role': 'system', 'message.content':...
#
#                                             attributes.output.value  \
# context.span_id
# 8d2de1581a113ca   In fields of gold where sunbeams dance,  \nBen...
# feb2c01e935b49f9                    The capital of Spain is Madrid.
#
#                  attributes.llm.token_count.completion_details.audio  \
# context.span_id
# 8d2de1581a113ca                                                   0
# feb2c01e935b49f9                                                  0
#
#                  attributes.llm.token_count.prompt
# context.span_id
# 8d2de1581a113ca                                 22
# feb2c01e935b49f9                                18
#
# [2 rows x 30 columns]

# %% [markdown]
# # Arize Setup

# %%
# !pip install -qe '..[spans]'
# !pip install -q 'arize[spans]==8.0.0a2'
# !pip freeze | grep arize
# Out:
# -e git+ssh://git@github.com/Arize-ai/arize.git@39e7012c38b85a4d6321da556e41037c36591556#egg=arize&subdirectory=sdk/python/loggerv8
# arize-phoenix-client==1.21.0

# %%
SPACE_ID = "U3BhY2U6NTA3MDpsTlIr"
PROJECT_NAME = "test-sdkv8-10-28-25-a"

# %%
import os

os.environ["ARIZE_LOG_ENABLE"] = "true"
os.environ["ARIZE_LOG_LEVEL"] = "debug"
os.environ["ARIZE_LOG_STRUCTURED"] = "false"

# %% [markdown]
# # Spans

# %%
import logging

from arize import ArizeClient

client = ArizeClient() # API key from env var

print("arize handlers:", logging.getLogger("arize").handlers)
print(
    "arize.spans.client handlers:",
    logging.getLogger("arize.spans.client").handlers,
)

print(client)
# Out:
# arize handlers: [<StreamHandler stdout (DEBUG)>]
# arize.spans.client handlers: []
# ArizeClient(
#   sdk_config=SDKConfiguration(
#     api_key='ak-ed5***',
#     api_host='api.arize.com',
#     api_scheme='https',
#     otlp_host='otlp.arize.com',
#     otlp_scheme='https',
#     flight_server_host='flight.arize.com',
#     flight_server_port=443,
#     flight_scheme='grpc+tls',
#     pyarrow_max_chunksize=10000,
#     request_verify=True,
#     stream_max_workers=8,
#     stream_max_queue_bound=5000,
#     max_http_payload_size_mb=100.0,
#     arize_direcory='~/.arize',
#     enable_caching=True,
#   )
#   subclients={
#     'datasets': lazy,
#     'experiments': lazy,
#     'spans': lazy,
#     'models': lazy,
#   }
# )

# %%
response = client.spans.log(
    space_id=SPACE_ID,
    project_name=PROJECT_NAME,
    dataframe=spans_df,
)

# If successful, the server will return a status_code of 200
if response.status_code != 200:
    print(
        f"❌ logging failed with response code {response.status_code}, {response.text}"
    )
else:
    print("✅ You have successfully logged training set to Arize")

cacacaca
# Out:
#   arize._lazy | DEBUG | Lazily loading subclient 'spans'
#   arize.spans.client | DEBUG | Performing direct input type validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.client | DEBUG | Performing dataframe form validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.validation.spans.dataframe_form_validation | INFO | Found columns that are not part of the Open Inference Specification and will be ignored | extra_columns=['attributes.llm.system', 'attributes.llm.token_count.prompt_details.cache_read', 'attributes.llm.provider', 'attributes.llm.token_count.completion_details.reasoning', 'attributes.llm.token_count.prompt_details.audio', 'attributes.url', 'attributes.llm.token_count.total', 'attributes.llm.token_count.completion', 'attributes.llm.token_count.completion_details.audio', 'attributes.llm.token_count.prompt']
#   arize.spans.client | DEBUG | Removing unnecessary columns | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.client | DEBUG | Converting timestamps | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.client | DEBUG | Performing values validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.client | DEBUG | Converting dictionaries to JSON objects | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.spans.client | DEBUG | Converting data to Arrow format | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True spans_df_rows=2 evals_df_rows=0
#   arize.utils.arrow | DEBUG | Preparing to log Arrow table via file upload
#   arize.utils.arrow | DEBUG | Preparing to log Arrow table via file upload | rows=2 cols=20
#   arize.utils.arrow | DEBUG | Serializing schema
#   arize.utils.arrow | DEBUG | Writing table to temporary file: /var/folders/53/611kkp5s3ds5yjcy4_sl8yw80000gn/T/tmpb_uhhfnk/arize-qnfgdu19.arrow
#   arize.utils.arrow | DEBUG | Uploading file to Arize | path='/var/folders/53/611kkp5s3ds5yjcy4_sl8yw80000gn/T/tmpb_uhhfnk/arize-qnfgdu19.arrow' size_bytes=11464
#   arize.utils.arrow | INFO | ✅ Success! Check out your data at https://app.arize.com/organizations/QWNjb3VudE9yZ2FuaXphdGlvbjoxOkNBWmo=/spaces/U3BhY2U6NTA3MDpsTlIr/models/modelName/test-sdkv8-10-28-25-a?selectedTab=llmTracing
# ✅ You have successfully logged training set to Arize
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      12 else:
#      13     print("✅ You have successfully logged training set to Arize")
# ---> 15 cacacaca
#
# NameError: name 'cacacaca' is not defined

# %% [markdown]
# # Evals

# %%
import pandas as pd

FORCE_HTTP = False
print(f"FORCE_HTTP = {FORCE_HTTP}")

# SPAN_ID = "c07fd230c8158330" # demo_llama_index
SPAN_ID = "8d2de1581a113ca"  # playground

eval_name = f"force_http_{str(FORCE_HTTP)}"

evaluation_data = {
    "context.span_id": [SPAN_ID],  # Use your span_id
    f"eval.{eval_name}.label": ["accuracy"],  # Example label name
    f"eval.{eval_name}.score": [0.8],  # Example label value
    f"eval.{eval_name}.explanation": ["some explanation"],
}
evals_df = pd.DataFrame(evaluation_data)
evals_df
# Out:
# FORCE_HTTP = False
#    context.span_id eval.force_http_False.label  eval.force_http_False.score  \
# 0  8d2de1581a113ca                    accuracy                          0.8
#
#   eval.force_http_False.explanation
# 0                  some explanation

# %%
response = client.spans.update_evaluations(
    space_id=SPACE_ID,
    project_name=PROJECT_NAME,
    dataframe=evals_df,
    force_http=FORCE_HTTP,
)
print(response)
cacaca
# Out:
#   arize.spans.client | DEBUG | Performing direct input type validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Performing dataframe form validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Removing unnecessary columns | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Performing values validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Converting data to Arrow format | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | WARNING | Flight update response missing counts | project='test-sdkv8-10-28-25-a' request_type='EVALUATION' total_spans=1 spans_processed=None spans_updated=1 spans_failed=None success_rate=None error_count=0
# {'records_updated': '1'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       1 response = client.spans.update_evaluations(
#       2     space_id=SPACE_ID,
#       3     project_name=PROJECT_NAME,
#       4     dataframe=evals_df,
#       5     force_http=FORCE_HTTP,
#       6 )
#       7 print(response)
# ----> 8 cacaca
#
# NameError: name 'cacaca' is not defined

# %% [markdown]
# # Annotations

# %%
annotation_data = {
    "context.span_id": [SPAN_ID],
    "annotation.quality.label": ["good"],
    "annotation.relevance.label": ["relevant"],
    "annotation.relevance.updated_by": ["human_annotator_1"],
    "annotation.sentiment_score.score": [4.5],
    "annotation.notes": ["User confirmed the summary was helpful."],
}
annotations_df = pd.DataFrame(annotation_data)

# %%
response = client.spans.update_annotations(
    space_id=SPACE_ID,
    project_name=PROJECT_NAME,
    dataframe=annotations_df,
)
print(response)
cacaca
# Out:
#   arize.spans.client | DEBUG | Checking for and autogenerating missing updated_by/updated_at annotation columns | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Found annotation names: {'relevance', 'quality', 'sentiment_score'} | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Autogenerating column: annotation.relevance.updated_at | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Autogenerating column: annotation.quality.updated_by | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Autogenerating column: annotation.quality.updated_at | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Autogenerating column: annotation.sentiment_score.updated_by | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Autogenerating column: annotation.sentiment_score.updated_at | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Formatting annotation.notes column to JSON strings within lists. | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Performing direct input type validation for annotations | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Performing dataframe form validation for annotations | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Removing unnecessary annotation columns | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Performing annotation values validation | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Converting data to Arrow format | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | WARNING | Flight update response missing counts | project='test-sdkv8-10-28-25-a' request_type='ANNOTATION' total_spans=1 spans_processed=None spans_updated=1 spans_failed=None success_rate=None error_count=0
# {'records_updated': '1'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       1 response = client.spans.update_annotations(
#       2     space_id=SPACE_ID,
#       3     project_name=PROJECT_NAME,
#       4     dataframe=annotations_df,
#       5 )
#       6 print(response)
# ----> 7 cacaca
#
# NameError: name 'cacaca' is not defined

# %% [markdown]
# # Metadata

# %%
metadata_df = pd.DataFrame(
    {
        "context.span_id": [SPAN_ID + "wrong"],
        "attributes.metadata.status": ["reviewed"],
        "attributes.metadata.tag": ["important"],
    }
)

# %%
response = client.spans.update_metadata(
    space_id=SPACE_ID,
    project_name=PROJECT_NAME,
    dataframe=metadata_df,
)
print(response)
cacca
# Out:
#   arize.spans.client | DEBUG | Found 2 metadata field columns with prefix 'attributes.metadata.' | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Validating metadata update input | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Validating metadata update dataframe form | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Validating metadata update values | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Using column names: context.span_id and patch_document | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | DEBUG | Converting data to Arrow format | resource='spans' operation='log' space_id='U3BhY2U6NTA3MDpsTlIr' project='test-sdkv8-10-28-25-a' validate=True evals_df_rows=1
#   arize.spans.client | INFO | ✅ All spans processed | project='test-sdkv8-10-28-25-a' request_type='METADATA' total_spans=1 spans_processed=1 spans_updated=0 spans_failed=1 success_rate=0.0 error_count=1
#   arize.spans.client | ERROR | Span update error | project='test-sdkv8-10-28-25-a' request_type='METADATA' span_id='8d2de1581a113cawrong' error_message='[segment_not_found] No matching interval found for span'
# {'spans_processed': '1', 'spans_failed': '1', 'errors': [{'span_id': '8d2de1581a113cawrong', 'error_message': '[segment_not_found] No matching interval found for span'}]}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       1 response = client.spans.update_metadata(
#       2     space_id=SPACE_ID,
#       3     project_name=PROJECT_NAME,
#       4     dataframe=metadata_df,
#       5 )
#       6 print(response)
# ----> 7 cacca
#
# NameError: name 'cacca' is not defined

# %% [markdown]
# # Export spans

# %%
from datetime import datetime

FMT = "%Y-%m-%d"
start_time = datetime.strptime("2024-01-01", FMT)
end_time = datetime.strptime("2026-01-01", FMT)
start_time, end_time

# %%
df = client.spans.export_to_df(
    space_id=SPACE_ID,
    project_name=PROJECT_NAME,
    start_time=start_time,
    end_time=end_time,
)
df.columns

# %%
cols_b = df.columns
len(cols_b)

# %%
cols_a = df.columns

# %%
len(cols_a)

# %%
cols_a
